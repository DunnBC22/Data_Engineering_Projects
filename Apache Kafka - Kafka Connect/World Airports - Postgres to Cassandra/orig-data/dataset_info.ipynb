# %%
import pandas as pd

# %%
df = pd.read_csv('World_Airports.csv')

df
# Out:
#             x_coord       y_coord  object_id      id airport_identifier  \
# 0     -1.301162e+07  4.212194e+06          1    6528               00CA
# 1     -9.034601e+06  3.347916e+06          2    6589               01FL
# 2     -1.309952e+07  4.104774e+06          3    6756               04CA
# 3     -1.011189e+07  3.887414e+06          4    6779               04MS
# 4     -1.287577e+07  4.267031e+06          5    6784               04NV
# ...             ...           ...        ...     ...                ...
# 75047 -1.543935e+07  8.578445e+06      75048  342103               ZYXW
# 75048  1.374751e+07  5.128738e+06      75049   32753               ZYYY
# 75049  1.650311e+05  6.781062e+06      75050   46378            ZZ-0001
# 75050  5.265010e+06 -1.298433e+06      75051  307326            ZZ-0002
# 75051 -1.546665e+07  1.086205e+07      75052  342102               ZZZW
#
#          airport_type                       airport_name  latitude_coord  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75052 entries, 0 to 75051
# Data columns (total 28 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   x_coord              75051 non-null  float64
#  1   y_coord              75051 non-null  float64
#  2   object_id            75052 non-null  int64
#  3   id                   75052 non-null  int64
#  4   airport_identifier   75052 non-null  object
#  5   airport_type         75052 non-null  object
#  6   airport_name         75052 non-null  object
#  7   latitude_coord       75052 non-null  float64
#  8   longitude_coord      75052 non-null  float64
#  9   elevation_ft         60789 non-null  float64
#  10  continent            38826 non-null  object
#  11  iso_country          74793 non-null  object
#  12  iso_region           75052 non-null  object
#  13  municipality         70060 non-null  object
#  14  scheduled_service    75052 non-null  object
# ...

# %%
df.nunique()
# Out:
# x_coord                73942
# y_coord                73666
# object_id              75052
# id                     75052
# airport_identifier     75052
# airport_type               7
# airport_name           71063
# latitude_coord         73820
# longitude_coord        74079
# elevation_ft            6188
# continent                  6
# iso_country              244
# iso_region              2878
# municipality           33832
# scheduled_service          2
# gps_code               41172
# iata_code               8868
# local_code             31079
# home_link               3573
# wikipedia_link         10797
# keywords               16312
# communications_desc     2292
# frequency_mhz           1142
# runway_length_ft        4827
# runway_width_ft          324
# runway_surface           585
# runway_lighted             2
# runway_closed              2
# dtype: int64

# %%
string_columns = df.select_dtypes(include=['object'])

# Function to find length of longest string in a column, skipping non-string values
def longest_string_length(column):
    string_lengths = column.apply(lambda x: len(x) if isinstance(x, str) else 0)
    return max(string_lengths)

# Find length of longest string value for each string column
longest_lengths = string_columns.apply(longest_string_length)
print(longest_lengths)
# Out:
# airport_identifier       7
# airport_type            14
# airport_name            93
# continent                2
# iso_country              2
# iso_region               7
# municipality            51
# scheduled_service        3
# gps_code                 4
# iata_code                3
# local_code               7
# home_link              128
# wikipedia_link         128
# keywords               256
# communications_desc     64
# runway_surface          63
# dtype: int64
