# %%
# imports
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(
    '/Users/briandunn/Desktop/Large Data Files/Iowa_Liquor_Sales/data/Iowa_Liquor_Sales.csv', 
    engine='c')

df
# Out:
# /var/folders/93/v_c2ph_17t97zdkzc4_ccjtw0000gn/T/ipykernel_64513/375590318.py:1: DtypeWarning: Columns (6,14,18,19,20,22,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(
#          Invoice/Item Number        Date  Store Number  \
# 0            INV-07718300026  10/05/2017          4091
# 1            INV-07790400037  10/09/2017          2651
# 2            INV-07747400001  10/05/2017          3831
# 3            INV-07622300001  10/03/2017          5140
# 4            INV-07688900026  10/04/2017          2623
# ...                      ...         ...           ...
# 27489738     INV-07782800011  10/06/2017          4268
# 27489739     INV-07743100018  10/05/2017          4539
# 27489740     INV-07829100005  10/09/2017          5299
# 27489741     INV-07731700060  10/05/2017          2528
# 27489742     INV-07657700040  10/04/2017          2806
#
#                                     Store Name             Address  \
# ...

# %%
df.describe(include='all')
# Out:
#        Invoice/Item Number        Date  Store Number  \
# count             27489743    27489743  2.748974e+07
# unique            27489743        3021           NaN
# top        INV-07718300026  12/27/2022           NaN
# freq                     1       18965           NaN
# mean                   NaN         NaN  3.858839e+03
# std                    NaN         NaN  1.210793e+03
# min                    NaN         NaN  2.106000e+03
# 25%                    NaN         NaN  2.621000e+03
# 50%                    NaN         NaN  3.869000e+03
# 75%                    NaN         NaN  4.748000e+03
# max                    NaN         NaN  1.027000e+04
#
#                           Store Name          Address        City    Zip Code  \
# count                       27489743         27407029    27407030  27406963.0
# unique                          3175             2982         483      1015.0
# top     HY-VEE #3 / BDI / DES MOINES  3221 SE 14TH ST  DES MOINES     50010.0
# ...

# %%
print("# of Unique Store Numbers: ", df['Store Number'].nunique())
print("# of Unique Store Names: ", df['Store Name'].nunique())
# Out:
# # of Unique Store Numbers:  2982
# # of Unique Store Names:  3175

# %%
corr_matrix = df.corr(method='pearson')

# %%
corr_matrix
# Out:
#                                     Store Number  County Number  Category  \
# Store Number                            1.000000      -0.009919  0.017890
# County Number                          -0.009919       1.000000 -0.003950
# Category                                0.017890      -0.003950  1.000000
# Vendor Number                           0.036737      -0.002488  0.068010
# Pack                                    0.093514       0.021322 -0.054018
# Iowa ZIP Code Tabulation Areas          0.006692      -0.001208  0.004013
# Iowa Watershed Sub-Basins (HUC 08)     -0.043419       0.229723 -0.005568
# Iowa Watersheds (HUC 10)               -0.008308       0.129465 -0.001950
# County Boundaries of Iowa              -0.037425       0.308663 -0.002428
#
#                                     Vendor Number      Pack  \
# Store Number                             0.036737  0.093514
# County Number                           -0.002488  0.021322
# ...

# %%
plt.figure(figsize=(12,12))
sns.heatmap(corr_matrix, annot=True, fmt='0.2f', square=True)
plt.show()

# %%
unique_counts = df.nunique()

print(unique_counts)
# Out:
# Invoice/Item Number                   27489743
# Date                                      3021
# Store Number                              2982
# Store Name                                3175
# Address                                   2982
# City                                       483
# Zip Code                                  1015
# Store Location                            9411
# County Number                               99
# County                                     100
# Category                                   114
# Category Name                              103
# Vendor Number                              469
# Vendor Name                                591
# Item Number                              15056
# Item Description                         11877
# Pack                                        28
# Bottle Volume (ml)                          58
# State Bottle Cost                         6385
# State Bottle Retail                       7295
# ...

# %%
pd.set_option('display.max_seq_items', None)

# %%
df['Iowa ZIP Code Tabulation Areas'].unique().tolist()
# Out:
# [171.0,
#  119.0,
#  264.0,
#  286.0,
#  248.0,
#  763.0,
#  850.0,
#  726.0,
#  445.0,
#  780.0,
#  253.0,
#  586.0,
#  583.0,
#  752.0,
#  153.0,
#  881.0,
#  146.0,
#  298.0,
#  438.0,
#  528.0,
#  315.0,
#  579.0,
#  133.0,
#  308.0,
#  806.0,
#  465.0,
#  609.0,
#  793.0,
#  233.0,
#  170.0,
#  349.0,
#  196.0,
#  172.0,
#  656.0,
#  654.0,
#  845.0,
#  85.0,
#  540.0,
#  nan,
#  803.0,
#  353.0,
#  87.0,
#  84.0,
#  551.0,
#  229.0,
#  832.0,
#  472.0,
#  89.0,
#  705.0,
#  619.0,
#  799.0,
#  607.0,
#  484.0,
#  385.0,
#  764.0,
#  326.0,
#  96.0,
#  496.0,
#  14.0,
#  916.0,
#  549.0,
#  614.0,
#  387.0,
#  877.0,
#  210.0,
#  917.0,
#  647.0,
#  621.0,
#  805.0,
#  246.0,
#  700.0,
#  543.0,
#  743.0,
#  27.0,
#  163.0,
#  511.0,
#  817.0,
#  681.0,
#  914.0,
#  194.0,
#  869.0,
#  4.0,
#  93.0,
#  118.0,
#  145.0,
#  409.0,
#  768.0,
#  185.0,
#  811.0,
#  432.0,
#  99.0,
#  483.0,
#  227.0,
#  536.0,
#  706.0,
#  251.0,
#  219.0,
#  587.0,
#  560.0,
#  217.0,
#  503.0,
# ...

# %%
df["Iowa Watersheds (HUC 10)"].unique().tolist()
# Out:
# [19.0,
#  190.0,
#  314.0,
#  429.0,
#  213.0,
#  508.0,
#  231.0,
#  86.0,
#  180.0,
#  479.0,
#  264.0,
#  292.0,
#  80.0,
#  333.0,
#  315.0,
#  109.0,
#  130.0,
#  287.0,
#  152.0,
#  354.0,
#  415.0,
#  121.0,
#  124.0,
#  83.0,
#  205.0,
#  417.0,
#  265.0,
#  319.0,
#  118.0,
#  84.0,
#  352.0,
#  165.0,
#  nan,
#  120.0,
#  342.0,
#  132.0,
#  75.0,
#  254.0,
#  356.0,
#  277.0,
#  312.0,
#  37.0,
#  363.0,
#  246.0,
#  72.0,
#  147.0,
#  193.0,
#  332.0,
#  316.0,
#  355.0,
#  419.0,
#  140.0,
#  331.0,
#  103.0,
#  534.0,
#  463.0,
#  219.0,
#  244.0,
#  279.0,
#  280.0,
#  421.0,
#  183.0,
#  437.0,
#  96.0,
#  360.0,
#  62.0,
#  413.0,
#  220.0,
#  313.0,
#  240.0,
#  76.0,
#  49.0,
#  198.0,
#  241.0,
#  20.0,
#  149.0,
#  330.0,
#  448.0,
#  245.0,
#  233.0,
#  281.0,
#  207.0,
#  345.0,
#  217.0,
#  359.0,
#  323.0,
#  126.0,
#  284.0,
#  82.0,
#  503.0,
#  242.0,
#  320.0,
#  134.0,
#  36.0,
#  131.0,
#  491.0,
#  59.0,
#  232.0,
#  343.0,
#  223.0,
#  171.0,
# ...

# %%
df["Iowa Watershed Sub-Basins (HUC 08)"].unique().tolist()
# Out:
# [20.0,
#  14.0,
#  25.0,
#  37.0,
#  35.0,
#  52.0,
#  18.0,
#  56.0,
#  27.0,
#  49.0,
#  22.0,
#  7.0,
#  10.0,
#  11.0,
#  13.0,
#  29.0,
#  36.0,
#  16.0,
#  19.0,
#  26.0,
#  24.0,
#  nan,
#  43.0,
#  21.0,
#  3.0,
#  30.0,
#  15.0,
#  9.0,
#  54.0,
#  46.0,
#  40.0,
#  8.0,
#  55.0,
#  5.0,
#  33.0,
#  41.0,
#  44.0,
#  12.0,
#  51.0,
#  38.0,
#  28.0,
#  4.0,
#  23.0,
#  42.0,
#  47.0,
#  50.0,
#  6.0,
#  39.0,
#  31.0,
#  1.0,
#  17.0,
#  34.0,
#  48.0,
#  45.0,
#  53.0]

# %%
df['Zip Code'].unique().tolist()
# Out:
# [50428.0,
#  50677.0,
#  50156.0,
#  51012.0,
#  51104.0,
#  50144.0,
#  51106.0,
#  50601.0,
#  52772.0,
#  50129.0,
#  50801.0,
#  52405.0,
#  52317.0,
#  52401.0,
#  52060.0,
#  50266.0,
#  50276.0,
#  52637.0,
#  50054.0,
#  52241.0,
#  52641.0,
#  50265.0,
#  52761.0,
#  50213.0,
#  51201.0,
#  52632.0,
#  52726.0,
#  50010.0,
#  52404.0,
#  52722.0,
#  50436.0,
#  51031.0,
#  52402.0,
#  50447.0,
#  52601.0,
#  50111.0,
#  52801.0,
#  50225.0,
#  50511.0,
#  52627.0,
#  50131.0,
#  50317.0,
#  50219.0,
#  52046.0,
#  51537.0,
#  50321.0,
#  51108.0,
#  50158.0,
#  50501.0,
#  52159.0,
#  52501.0,
#  52804.0,
#  51521.0,
#  51360.0,
#  50707.0,
#  52087.0,
#  52556.0,
#  52753.0,
#  50459.0,
#  50309.0,
#  50138.0,
#  51331.0,
#  52353.0,
#  50322.0,
#  50220.0,
#  52751.0,
#  52544.0,
#  51573.0,
#  50401.0,
#  51101.0,
#  51442.0,
#  50703.0,
#  51105.0,
#  52342.0,
#  50021.0,
#  50142.0,
#  51301.0,
#  50616.0,
#  50435.0,
#  50315.0,
#  50613.0,
#  52301.0,
#  51503.0,
# ...

# %%
pd.reset_option('display.max_seq_items')

# %%
shorter_list = ['store_number',
                'store_name',
                'store_city',
                'store_zip_code',
                'store_county',
                'item_category',
                'category_name',
                'vendor_name',
                'state_bottle_cost',
                'state_bottle_retail',
                'sale_dollars',
                'iowa_zipcode_tab_areas',
                'iowa_watershed_sub_basins',
                'iowa_watersheds',
                'iowa_county_boundaries',
                'us_counties'
                ]

longer_list = [
    "store_number",
    "store_name",
    "store_city",
    "store_zip_code",
    "store_county",
    "item_category",
    "category_name",
    "vendor_name",
    "pack",
    "bottle_volume",
    "state_bottle_cost",
    "state_bottle_retail",
    "bottles_sold",
    "sale_dollars",
    "volume_sold_gallons",
    "iowa_zipcode_tab_areas",
    "iowa_watershed_sub_basins",
    "iowa_watersheds",
    "iowa_county_boundaries",
    "us_counties",
    "sales_year",
    "sales_month",
    "sales_day"
]

diff = [item for item in longer_list if item not in shorter_list]

diff
# Out:
# ['pack',
#  'bottle_volume',
#  'bottles_sold',
#  'volume_sold_gallons',
#  'sales_year',
#  'sales_month',
#  'sales_day']

# %%
zippy_issues = df[df['Zip Code'] == '712-2']

zippy_issues
# Out:
#          Invoice/Item Number        Date  Store Number  \
# 169174       INV-00258800023  09/12/2016          4307
# 172660       INV-00260000025  09/12/2016          4307
# 173564       INV-00258800032  09/12/2016          4307
# 173582       INV-00258800018  09/12/2016          4307
# 174466       INV-00258800015  09/12/2016          4307
# ...                      ...         ...           ...
# 25758664     INV-02396600059  12/26/2016          4307
# 25763972     INV-02396600024  12/26/2016          4307
# 25768870     INV-02396600005  12/26/2016          4307
# 25771499     INV-02396600054  12/26/2016          4307
# 25772295     INV-02396600052  12/26/2016          4307
#
#                           Store Name       Address    City Zip Code  \
# 169174    CROSSROADS WINE AND LIQUOR  117 IOWA AVE  DUNLAP    712-2
# 172660    CROSSROADS WINE AND LIQUOR  117 IOWA AVE  DUNLAP    712-2
# 173564    CROSSROADS WINE AND LIQUOR  117 IOWA AVE  DUNLAP    712-2
# ...

# %%
zippy_issues['Store Number'].unique()[0]
# Out:
# 4307

# %%
zippy_issues_2 = df[df['Store Number'] == 4307]

zippy_issues_2
# Out:
#          Invoice/Item Number        Date  Store Number  \
# 169174       INV-00258800023  09/12/2016          4307
# 172660       INV-00260000025  09/12/2016          4307
# 173564       INV-00258800032  09/12/2016          4307
# 173582       INV-00258800018  09/12/2016          4307
# 174466       INV-00258800015  09/12/2016          4307
# ...                      ...         ...           ...
# 25758664     INV-02396600059  12/26/2016          4307
# 25763972     INV-02396600024  12/26/2016          4307
# 25768870     INV-02396600005  12/26/2016          4307
# 25771499     INV-02396600054  12/26/2016          4307
# 25772295     INV-02396600052  12/26/2016          4307
#
#                           Store Name       Address    City Zip Code  \
# 169174    CROSSROADS WINE AND LIQUOR  117 IOWA AVE  DUNLAP    712-2
# 172660    CROSSROADS WINE AND LIQUOR  117 IOWA AVE  DUNLAP    712-2
# 173564    CROSSROADS WINE AND LIQUOR  117 IOWA AVE  DUNLAP    712-2
# ...
