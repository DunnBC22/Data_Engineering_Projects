# %%
import pandas as pd

# %%
df = pd.read_csv("data-loader/data/orig-data.csv")

df
# Out:
#        transaction_type  actual_days_to_ship  scheduled_days_to_ship  \
# 0                 DEBIT                    3                       4
# 1              TRANSFER                    5                       4
# 2                  CASH                    4                       4
# 3                 DEBIT                    3                       4
# 4               PAYMENT                    2                       4
# ...                 ...                  ...                     ...
# 180514             CASH                    4                       4
# 180515            DEBIT                    3                       2
# 180516         TRANSFER                    5                       4
# 180517          PAYMENT                    3                       4
# 180518          PAYMENT                    4                       4
#
#         benefit_per_order  sales_per_customer   delivery_status  \
# 0               91.250000          314.640015  Advance shipping
# ...

# %%
df.to_csv("data-loader/data/data.csv", index_label='record_id')
