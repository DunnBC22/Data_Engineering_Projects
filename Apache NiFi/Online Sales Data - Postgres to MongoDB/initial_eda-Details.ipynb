# %%
import pandas as pd
import os

# %%
df = pd.read_csv("pg_scripts/Details.csv")

df
# Out:
#      order_id  amount  profit  quantity     category      sub_category  \
# 0     B-25681    1096     658         7  Electronics  Electronic Games
# 1     B-26055    5729      64        14    Furniture            Chairs
# 2     B-25955    2927     146         8    Furniture         Bookcases
# 3     B-26093    2847     712         8  Electronics          Printers
# 4     B-25602    2617    1151         4  Electronics            Phones
# ...       ...     ...     ...       ...          ...               ...
# 1495  B-25700       7      -3         2     Clothing       Hankerchief
# 1496  B-25757    3151     -35         7     Clothing          Trousers
# 1497  B-25973    4141    1698        13  Electronics          Printers
# 1498  B-25698       7      -2         1     Clothing       Hankerchief
# 1499  B-25993    4363     305         5    Furniture            Tables
#
#      payment_mode
# 0             COD
# 1             EMI
# 2             EMI
# 3     Credit Card
# 4     Credit Card
# ...           ...
# 1495          COD
# 1496          EMI
# 1497          COD
# 1498          COD
# 1499          EMI
#
# [1500 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   order_id      1500 non-null   object
#  1   amount        1500 non-null   int64
#  2   profit        1500 non-null   int64
#  3   quantity      1500 non-null   int64
#  4   category      1500 non-null   object
#  5   sub_category  1500 non-null   object
#  6   payment_mode  1500 non-null   object
# dtypes: int64(3), object(4)
# memory usage: 82.2+ KB

# %%
df.describe()
# Out:
#             amount      profit     quantity
# count  1500.000000  1500.00000  1500.000000
# mean    291.847333    24.64200     3.743333
# std     461.924620   168.55881     2.184942
# min       4.000000 -1981.00000     1.000000
# 25%      47.750000   -12.00000     2.000000
# 50%     122.000000     8.00000     3.000000
# 75%     326.250000    38.00000     5.000000
# max    5729.000000  1864.00000    14.000000

# %%
df.nunique()
# Out:
# order_id        500
# amount          590
# profit          406
# quantity         14
# category          3
# sub_category     17
# payment_mode      5
# dtype: int64

# %%
# Count null values per column
null_counts = df.isnull().sum()
null_counts
# Out:
# order_id        0
# amount          0
# profit          0
# quantity        0
# category        0
# sub_category    0
# payment_mode    0
# dtype: int64

# %%
cutoff = 100

for col in df.columns:
    unique_vals = df[col].unique()
    if len(unique_vals) < cutoff:
        print(f"{col} ({len(unique_vals)}): {unique_vals}")
    else:
        print(f"{col} ({len(unique_vals)})")
# Out:
# order_id (500)
# amount (590)
# profit (406)
# quantity (14): [ 7 14  8  4  5  2  9  6  1  3 13 11 10 12]
# category (3): ['Electronics' 'Furniture' 'Clothing']
# sub_category (17): ['Electronic Games' 'Chairs' 'Bookcases' 'Printers' 'Phones' 'Trousers'
#  'Saree' 'Hankerchief' 'Kurti' 'Skirt' 'Tables' 'Stole' 'Leggings'
#  'Accessories' 'T-shirt' 'Furnishings' 'Shirt']
# payment_mode (5): ['COD' 'EMI' 'Credit Card' 'UPI' 'Debit Card']

# %%
import pandas as pd
from tabulate import tabulate

def find_and_display_longest_strings(df):
    # Initialize a list to store results
    results = []
    
    # Iterate through columns
    for column in df.columns:
        # Check if the column has string (object) data type
        if df[column].dtype == 'object':
            # Find the longest string in the column
            longest_string_index = df[column].astype(str).str.len().idxmax()
            longest_string = df.loc[longest_string_index, column]
            # Store the result
            results.append([column, longest_string, len(longest_string)])
    
    # Create a DataFrame from the results
    result_df = pd.DataFrame(results, columns=['Column', 'Longest String', 'Length'])
    
    # Sort the results by length in descending order
    result_df = result_df.sort_values('Length', ascending=False).reset_index(drop=True)
    
    # Display the results in a pretty table
    print("\nLongest Strings in Each Column:")
    print(tabulate(result_df, headers='keys', tablefmt='pretty', showindex=False))
    
    return result_df


result = find_and_display_longest_strings(df)
# Out:
# Longest Strings in Each Column:
# +--------------+------------------+--------+
# |    Column    |  Longest String  | Length |
# +--------------+------------------+--------+
# | sub_category | Electronic Games |   16   |
# |   category   |   Electronics    |   11   |
# | payment_mode |   Credit Card    |   11   |
# |   order_id   |     B-25681      |   7    |
# +--------------+------------------+--------+
