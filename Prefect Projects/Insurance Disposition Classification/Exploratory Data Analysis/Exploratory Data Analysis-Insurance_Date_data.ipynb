# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### Import Libraries

# %%
import sys
import polars as pl
import polars.selectors as pol_sel

# %% [markdown]
# ### Show Python & Library Versions

# %%
l = 8
r = 12

print("Python".rjust(l), ":", sys.version[0:6].ljust(r))
print("Polars".rjust(l), ":", pl.__version__.ljust(r))
# Out:
#   Python : 3.11.4
#   Polars : 1.12.0

# %% [markdown]
# ## Exploratory Data Analysis with Polars

# %% [markdown]
# ### Load CSV File into Polars DataFrame

# %%
df = pl.read_csv("../data/Insurance_Date_data.csv",
                 ignore_errors=True)

df
# Out:
# shape: (34_110, 3)
# ┌──────────────┬───────────────┬───────────────┐
# │ Claim Number ┆ Incident Date ┆ Date Received │
# │ ---          ┆ ---           ┆ ---           │
# │ str          ┆ str           ┆ str           │
# ╞══════════════╪═══════════════╪═══════════════╡
# │ BCHKRDM32K   ┆ 21-10-2007    ┆ 31-10-2007    │
# │ B3GPD5IZQW   ┆ 26-05-2006    ┆ 14-06-2006    │
# │ EB757CV6XW   ┆ 18-01-2004    ┆ 10-02-2004    │
# │ SP0Z0Q95OV   ┆ 28-04-2004    ┆ 06-05-2004    │
# │ VKZUK7J3KK   ┆ 04-11-2007    ┆ 14-11-2007    │
# │ …            ┆ …             ┆ …             │
# │ AF9GJPNKEX   ┆ 04-11-2004    ┆ 18-11-2004    │
# │ IB6C791V95   ┆ 23-12-2005    ┆ 23-02-2006    │
# │ PGEDMDDHC2   ┆ 07-09-2007    ┆ 11-09-2007    │
# │ MNSM4JN71E   ┆ 05-12-2004    ┆ 28-12-2004    │
# │ 5YKXQ6YTNM   ┆ 12-05-2007    ┆ 24-09-2007    │
# └──────────────┴───────────────┴───────────────┘

# %%
column_data_types = zip(df.columns, df.dtypes)

for column, dtype in column_data_types:
    print(f"{column}:\t\t{dtype}")
# Out:
# Claim Number:		String
# Incident Date:		String
# Date Received:		String

# %% [markdown]
# ### Display Summary Statistics for All Columns

# %%
summary = df.describe()
print(summary)
# Out:
# shape: (9, 4)
# ┌────────────┬──────────────┬───────────────┬───────────────┐
# │ statistic  ┆ Claim Number ┆ Incident Date ┆ Date Received │
# │ ---        ┆ ---          ┆ ---           ┆ ---           │
# │ str        ┆ str          ┆ str           ┆ str           │
# ╞════════════╪══════════════╪═══════════════╪═══════════════╡
# │ count      ┆ 34110        ┆ 34110         ┆ 34110         │
# │ null_count ┆ 0            ┆ 0             ┆ 0             │
# │ mean       ┆ null         ┆ null          ┆ null          │
# │ std        ┆ null         ┆ null          ┆ null          │
# │ min        ┆ 000TQE7Z0O   ┆ 01-01-2003    ┆ 01-01-2009    │
# │ 25%        ┆ null         ┆ null          ┆ null          │
# │ 50%        ┆ null         ┆ null          ┆ null          │
# │ 75%        ┆ null         ┆ null          ┆ null          │
# │ max        ┆ ZZW9JKTJMJ   ┆ 31-12-2008    ┆ 31-12-2009    │
# └────────────┴──────────────┴───────────────┴───────────────┘

# %% [markdown]
# ### Count of Nulls In Each Feature

# %%
for col in df.columns:
    print(f"{col} : {df[col].is_null().sum()}")
# Out:
# Claim Number : 0
# Incident Date : 0
# Date Received : 0

# %% [markdown]
# ### Find Longest Text Length in Each Column

# %%
# Create an empty list to store max lengths for each string column
longest_text_lengths = []

# Loop through the columns to check for string columns
string_columns = [col for col in df.columns if df[col].dtype == pl.Utf8]

max_lengths = {}
for col in string_columns:
    max_length = df.select(pl.col(col).str.len_chars().max()).to_numpy()[0, 0]
    max_lengths[col] = max_length

df_max_lengths = pl.DataFrame(max_lengths)

df_max_lengths
# Out:
# shape: (1, 3)
# ┌──────────────┬───────────────┬───────────────┐
# │ Claim Number ┆ Incident Date ┆ Date Received │
# │ ---          ┆ ---           ┆ ---           │
# │ u32          ┆ u32           ┆ u32           │
# ╞══════════════╪═══════════════╪═══════════════╡
# │ 10           ┆ 10            ┆ 10            │
# └──────────────┴───────────────┴───────────────┘

# %% [markdown]
# ### Count Unique Values in Each Column

# %%
all_columns = [col for col in df.columns]

for col in all_columns:
    unique_counts = df[col].n_unique()
    print(f"Unique values in {col} :".rjust(48), f"{unique_counts}".ljust(6))
# Out:
#                  Unique values in Claim Number : 34110
#                 Unique values in Incident Date : 2685
#                 Unique values in Date Received : 1832

# %% [markdown]
# ### Retrieve Unique Values in Each Feature

# %%
for col in df.columns:
    unique_values = df[col].unique()
    print(f"'{col}' {len(unique_values)}: {unique_values.to_list()}")
# Out:
# 'Claim Number' 34110: ['IXCXH3BHQF', 'N3G1G3HB94', '6UHASV7YS4', 'OEJF421ZG7', '0WCDDOEBEZ', 'C31KN414O5', '9S49TVNCFW', 'OJPRU8HNU5', 'SY1DNGOSA4', '6OSTCDLXPW', 'WIZHYOHN73', '1NSBPB0V7F', 'W0BPMXS1MM', 'HWGK3RCTNC', 'TA3R7MQX0T', 'C3UBZBCPHN', 'BTVLAFU50F', 'IRGKY6JQC6', 'TXY0LV225I', 'VUECE45B1Y', '4T764P09CU', '5OI75NYHWP', 'M2K1EBYETT', '1Z9LSIHGH4', 'RGRT4AZTNX', 'OKICAMJYPJ', 'KBOD8MTAGR', 'VKLK275U2B', 'PEDIQTLK1P', 'HU7TEIM8EA', 'CY83FNWTK8', '948D17W889', '889WA8U4AF', 'SZQ9FYMEEG', '50O4BW9US1', '9MEXWK6WZ3', 'BUUFSDKUAL', 'LV7E8PYQR6', 'BZJOLW7LSD', '38R77TWS17', 'FBHYF5M5V9', '0KYR7CPTPS', 'TF6LE2UZ9C', '5KHVZXP024', '3RJEWDTWFS', 'F4ODO5XJ9G', 'ATXSIHQK9Z', 'ATNCWAN4HR', 'UB6JNABXW0', 'EW7BQ5WSJA', '8QOV8QS4PP', 'OOY2DR1O74', 'SSQ22QQQOS', '06E4EBKIM0', 'BTMNLQM63I', 'PW89EL7N22', 'G3A3Z3R1SI', 'XMQOY47XQ3', 'TJ4CQZX908', '23ZY301NZX', 'O74JJ7E07M', '72O68CII94', 'IS4OK9JFIG', '8PUVJG75DW', 'K610UTNML9', 'C50NP2MKWN', 'PSH9ZWW1HF', 'EACKRSQQ8O', 'R9HF1MBJAL', 'LQR1B0FQRS', 'NLWN00J4RA', 'DRPWZICBJ8', 'NTGWZ1R068', 'PJW6JUVMKH', 'M7SPB16BU7', 'JD6339K6BG', '48EIU19Y52', 'EWB632XCA4', 'R3PFODJLHS', 'QIK7S4W1AK', '1Z4FT3YI1Y', 'Z0K871853Y', 'AXH97S5M9S', '7GKT9DZH15', 'U91KNOB08W', 'H54ZK1491P', 'OV3NJSA4NH', 'J1PVC38WLT', '2WN3OROB4O', 'FZ2ZQT7L4Q', 'I7ITITDG6D', 'UZ0WL2NY8V', '2TSDWDYC29', 'OD4DTKJIY4', 'AMZVFYXG3F', '6234FDLBHQ', 'E3SIVSPEF2', 'NV6PRSTBPF', 'Z3ZN0LBAOI', 'CNNNZ7I5GO', 'KXLO5OVQJR', '81VQQE696G', 'KIPPZSH31M', '7MTY4OO4SV', 'QPC9IPEX5W', 'V5UCVZVCJQ', 'Y7H5GWFL67', 'UBKB8UAYCF', 'INKRWWJXSM', 'XJQBSRO2QL', '2IDRPW52ZY', '1HT5RFP3K8', 'R9CF4JQ64V', 'ZG1UB6K5X1', 'SQO7MA6K27', 'ICXCHCM9OY', 'VXH53BHQAL', 'ABHKRQ9NGC', '4T8MSJZH9K', 'GCMEQUOSU6', 'LE358JX7B3', 'A8PFK984IH', 'AIJBREI5BC', 'YEYHZ42QFD', 'VJ0JOOUQ83', '18KPCH1CZE', '98RDHJCO21', 'VT15VPU2EP', '4IXAELH3ZM', '9TB75LOICC', '2K4QFMFCQQ', '9GJM5IJ2S7', 'PK1O8R1L6Z', 'U0L6QMZAZ9', 'OLTKJRSUNI', 'L7L0WGF5Y7', '00P4JS0J3Y', 'I9F0VUDLH8', 'I05AJ8TK7M', '3M7C55ZTDL', 'HU7LLBCA2H', 'Y7Z5651659', 'XKQKJHMJJ1', 'AU3YTXK0FV', 'EDQGBY6SA1', '6EYEER7EYZ', 'M1O3GARUEV', 'IER3AEBS9L', 'DTBYZI7JBE', 'E5I1A5TFQD', 'F3TU17LBLW', '20BWP3SP8M', '600RKIFD7H', 'N360RMHCGY', 'KK5WPUHOA3', '3SI4XF9851', '46F5DOFM7P', 'EAK6IJIAKB', '60O1QHUQMS', 'BGBVX2I89F', '0RR8VFL8R4', 'RPFMBQI61G', 'PQ0OBRTC0W', 'TO96M495E2', 'CLADLEA60O', 'O7ILLLY1DI', 'RPSKET8Z8P', '4SSN6MYVKV', 'PL78XABLVW', 'MGIQGF08BS', 'N71CSQOIAD', 'C54MJ1A568', 'U7P2EESAP0', '4N926L6USN', 'O34YOQ1QBW', 'QLLLUCN42P', 'SBL4AUH7YY', 'V7NHXS4HDP', 'E4OOJ0YZT4', 'THI0ERWX3H', '3JVVZREFPI', 'UJR6K1UR7S', 'YM7DYPTO04', 'MJ7BFELVTS', 'IP7YOP6ONG', 'PEBF97TJ07', 'ULLVVHCRS3', 'Q4HO8WX4MB', '6NJNOZERTK', 'MD7DQ5CRJZ', 'KQVWBYFS3Y', '4MUKTMMAZ9', 'XE9KZUQAXL', '9KGEDMT142', '42P22VWUB9', 'P3Z9ZS3KXZ', '96NBMFFEP0', 'T5ZA5K1L68', 'JP32VEFE9O', 'QDMQIMBI7T', '924WA1OIYI', 'KS8L5ANWUH', 'OFFY5UMS3O', '9SSLFW6YDS', 'RB1NSJATLB', 'Q909NKFHB0', '2YDGKT9OO4', 'GHTB2O9LCS', 'L2061PING3', '4PFJSM0C4A', '2F06O647ES', 'BZ71FD6GZV', '12Z6JW1Q3C', 'CQ6L8MZEJQ', '55K64BNMIB', 'KLKX58KR3D', '6TEP9L7SIE', 'BB88WO147L', 'B0UNS0LSY4', '7N279LU1MX', 'FF6CHUP318', '3CXD1X1ELI', 'UFHYJW5XVV', 'GCGE66GG9T', '5X9ZKZXG9F', 'OB27OGZ39I', 'J3QNVLCQJB', 'CFPD31B2PW', 'RTZP8U3TW6', 'JX011GPUN3', 'V6BH3XAXYU', '1RQXWTGA5I', 'BPTIYUTE22', 'CDCLDN5MMK', '11U90X1RGZ', 'X9L601DQIC', 'KQDTWCAZFP', 'N0HZ6R9XZ7', 'TF7NOHJAVA', 'Y0VNQJKFJC', '1TMN6AQ6YT', 'YXB2GJNO5A', '40YL8B4VO1', '3KO37UX4I6', 'YH73LOOCBU', 'IRKZOWU7RW', 'YSBVY31TWR', 'NYZJOGF49E', 'S683FENS4G', 'ZRWF4084ZY', 'LWPFSPGNHS', '36UPFNZC6G', 'B3JCTPG10X', 'MZEXXUP605', 'RPQS6RZLZS', 'IK1ROB0PT6', '0EWX89O11K', 'JCABZ3DRF9', 'JK0DLQY2JJ', '9EA8JISJYF', 'DZZEK0EWHE', 'KF31UU6S8H', '5OT4RBY0EL', 'I25D8EEFMV', 'KNPMTGTNFX', 'JY4EH3G30B', '44TGK5R2KM', 'WN2LBISYCP', 'P4C5T0VTCH', 'UOSLGVUBOQ', 'MTL60750LV', '2S6BKJ511Z', 'BUWZFACEPA', 'I5AJCMC4AP', 'P55R0V437K', '1AQCKQR2KB', '19VCMC6AVC', '59YOLO6JMT', 'N1512V8H6C', '5CAW9XJDN6', 'VJHY059F9M', 'GFLWLHY1D7', '72UYZY4H9G', 'GZZCJ83N9O', ' ...
# 'Incident Date' 2685: ['04-10-2004', '23-05-2008', '22-04-2007', '03-05-2008', '20-09-2003', '07-08-2005', '03-01-2009', '04-10-2005', '19-07-2006', '20-05-2005', '13-04-2006', '23-06-2006', '11-06-2005', '23-04-2004', '11-05-2006', '19-07-2003', '16-10-2002', '23-10-2002', '17-02-2009', '31-08-2008', '20-10-2003', '13-05-2004', '23-12-2007', '22-12-2003', '23-09-2007', '23-08-2005', '12-06-2007', '11-05-2009', '20-06-2007', '17-09-2009', '30-05-2004', '25-10-2004', '22-08-2005', '21-08-2009', '16-04-2003', '29-08-2007', '23-03-2006', '25-12-2005', '10-07-2006', '07-09-2007', '06-11-2009', '06-07-2007', '03-09-2003', '25-12-2008', '28-02-2009', '03-02-2003', '22-12-2008', '16-07-2008', '21-10-2003', '23-03-2009', '23-12-2004', '01-12-2007', '09-01-2008', '05-11-2003', '17-10-2007', '24-07-2004', '10-10-2007', '19-04-2004', '08-04-2003', '21-12-2006', '29-07-2009', '03-10-2008', '18-04-2007', '22-12-2006', '28-03-2008', '17-03-2008', '18-09-2007', '21-05-2005', '23-05-2006', '01-04-2008', '16-02-2009', '08-11-2002', '11-01-2009', '22-01-2006', '18-06-2008', '06-03-2007', '23-10-2005', '05-07-2006', '16-04-2008', '30-09-2007', '03-01-2007', '11-03-2005', '29-08-2004', '24-02-2006', '12-08-2005', '23-04-2003', '02-10-2006', '17-07-2005', '17-03-2006', '28-05-2009', '09-01-2009', '18-08-2007', '05-11-2004', '20-08-2008', '07-07-2009', '23-07-2009', '13-03-2008', '24-10-2005', '07-10-2002', '16-02-2007', '04-05-2005', '28-06-2004', '05-01-2005', '02-06-2003', '13-07-2008', '22-03-2007', '01-01-2007', '19-09-2002', '16-09-2006', '25-10-2006', '08-11-2005', '24-09-2004', '21-07-2004', '28-08-2005', '18-09-2006', '20-07-2008', '21-10-2006', '26-12-2006', '01-01-2004', '07-02-2009', '02-09-2004', '20-02-2008', '21-10-2008', '05-02-2009', '02-05-2008', '23-07-2004', '31-10-2007', '27-03-2006', '18-11-2008', '17-11-2009', '11-08-2005', '05-09-2009', '19-10-2008', '04-12-2004', '29-09-2007', '29-10-2005', '20-05-2008', '21-03-2005', '20-03-2008', '16-02-2005', '15-11-2007', '09-03-2006', '03-11-2003', '15-02-2008', '22-06-2007', '26-08-2004', '11-10-2003', '24-11-2004', '13-10-2005', '06-01-2009', '08-07-2003', '10-09-2009', '16-06-2006', '02-05-2005', '20-07-2009', '07-12-2003', '25-04-2005', '29-12-2006', '25-11-2003', '29-03-2006', '19-02-2006', '28-12-2009', '10-05-2009', '27-10-2006', '29-07-2007', '23-01-2009', '20-09-2007', '19-02-2008', '22-08-2009', '18-02-2009', '20-01-2007', '05-09-2002', '27-07-2004', '04-01-2005', '15-01-2008', '11-02-2006', '16-06-2008', '16-04-2005', '08-03-2003', '19-10-2005', '08-02-2008', '02-10-2007', '02-09-2009', '11-11-2005', '27-02-2005', '19-01-2005', '06-11-2005', '21-08-2006', '09-11-2007', '18-07-2004', '06-09-2009', '04-08-2004', '05-03-2003', '25-08-2008', '01-06-2005', '22-11-2005', '05-10-2005', '13-01-2008', '03-05-2006', '13-10-2006', '25-09-2006', '11-10-2009', '12-06-2006', '12-10-2004', '18-05-2004', '28-12-2004', '08-10-2006', '02-03-2006', '25-10-2009', '06-04-2005', '02-04-2004', '23-06-2005', '22-05-2009', '01-09-2007', '03-02-2004', '11-08-2003', '19-03-2003', '07-01-2007', '12-08-2004', '21-05-2009', '04-10-2006', '21-06-2007', '26-10-2005', '27-11-2007', '24-10-2006', '13-02-2005', '14-11-2009', '06-05-2005', '15-03-2003', '21-05-2008', '13-09-2002', '23-11-2006', '23-03-2005', '15-01-2009', '04-09-2008', '03-12-2005', '18-10-2005', '02-08-2007', '03-08-2007', '02-03-2004', '26-04-2007', '26-01-2008', '13-01-2003', '22-03-2004', '19-12-2009', '14-12-2009', '20-11-2009', '23-01-2005', '17-03-2007', '01-10-2009', '26-10-2008', '11-10-2008', '21-04-2004', '05-11-2002', '17-05-2006', '19-12-2004', '30-06-2005', '18-09-2008', '19-03-2007', '02-09-2006', '29-09-2002', '20-03-2003', '21-12-2004', '14-09-2009', '18-12-2007', '18-05-2003', '18-12-2004', '15-11-2008', '22-11-2009', '18-08-2004', '19-09-2009', '08-06-2007', '17-03-2009', '13-10-2004', '29-10-2009', '09-10-2005', '27-03-2008', '12-09-2006', '13-07-2003', '07-03-2008', '14-07-2004', '20-04-2008', '19-04-2007', '18-01-2008', ' ...
# 'Date Received' 1832: ['17-02-2004', '27-01-2005', '04-01-2008', '09-10-2004', '27-01-2009', '31-03-2006', '03-02-2004', '12-07-2006', '24-03-2009', '04-12-2007', '24-10-2007', '19-10-2005', '03-06-2004', '18-07-2005', '01-02-2008', '19-03-2009', '11-02-2009', '22-04-2008', '27-11-2007', '08-06-2009', '14-12-2005', '16-06-2008', '22-12-2008', '26-03-2003', '17-07-2006', '30-05-2003', '10-08-2007', '15-07-2004', '22-12-2009', '28-03-2003', '23-11-2009', '06-11-2004', '20-05-2005', '04-06-2008', '10-04-2004', '13-06-2005', '12-08-2005', '29-11-2009', '07-11-2003', '21-11-2007', '24-08-2005', '26-04-2006', '06-11-2006', '25-02-2003', '14-01-2004', '09-03-2009', '12-05-2003', '11-10-2005', '27-10-2006', '06-11-2009', '10-12-2009', '28-01-2007', '21-05-2007', '28-10-2004', '21-12-2006', '15-01-2006', '19-09-2005', '09-06-2009', '15-04-2004', '28-07-2003', '28-12-2006', '26-01-2005', '17-04-2006', '23-10-2009', '10-07-2004', '28-03-2005', '09-10-2009', '11-03-2008', '20-12-2005', '18-11-2009', '30-05-2008', '19-08-2004', '12-12-2009', '22-03-2006', '30-07-2007', '17-12-2003', '24-10-2008', '07-01-2003', '29-01-2003', '26-05-2005', '15-11-2006', '03-04-2003', '09-06-2008', '12-06-2008', '23-02-2007', '23-12-2008', '05-12-2008', '13-10-2009', '21-04-2004', '23-11-2007', '17-09-2008', '02-09-2009', '08-01-2003', '11-06-2003', '12-09-2006', '13-02-2006', '13-02-2009', '08-10-2009', '10-12-2002', '28-06-2004', '25-01-2005', '04-03-2003', '03-11-2004', '27-11-2006', '05-06-2008', '28-10-2005', '30-06-2004', '05-02-2009', '17-12-2007', '30-06-2008', '03-06-2005', '16-03-2009', '28-11-2006', '11-03-2004', '15-12-2009', '29-11-2004', '07-08-2006', '15-05-2003', '08-02-2007', '27-04-2006', '28-09-2006', '08-09-2009', '30-05-2005', '02-11-2007', '28-03-2008', '12-12-2002', '10-07-2009', '16-02-2004', '01-11-2005', '03-09-2009', '12-04-2004', '13-11-2007', '13-04-2005', '07-05-2009', '22-03-2007', '05-11-2005', '22-11-2006', '07-12-2009', '20-05-2009', '14-04-2005', '16-03-2005', '20-03-2003', '16-08-2004', '29-06-2009', '11-06-2009', '24-03-2004', '21-04-2008', '26-04-2005', '14-05-2004', '28-10-2009', '24-11-2008', '28-08-2008', '05-10-2005', '31-03-2005', '15-01-2004', '25-09-2009', '27-03-2006', '03-07-2008', '01-02-2006', '11-08-2008', '05-03-2007', '16-11-2009', '18-04-2005', '10-06-2009', '04-08-2003', '13-11-2006', '14-11-2008', '05-07-2006', '14-01-2008', '29-09-2003', '22-10-2007', '24-12-2008', '09-07-2009', '16-12-2003', '26-03-2007', '08-07-2008', '12-09-2005', '02-04-2009', '05-08-2008', '25-07-2006', '01-04-2003', '21-07-2009', '14-12-2006', '14-11-2004', '20-06-2008', '29-07-2003', '15-05-2006', '03-05-2004', '17-10-2007', '22-03-2004', '28-06-2006', '17-11-2009', '10-09-2008', '06-11-2002', '25-10-2004', '10-09-2003', '06-01-2003', '11-09-2003', '22-04-2003', '12-11-2009', '02-03-2008', '13-06-2006', '20-03-2006', '02-09-2008', '24-07-2008', '13-12-2006', '23-01-2003', '14-04-2003', '07-02-2002', '16-08-2007', '10-01-2008', '09-04-2005', '09-12-2007', '19-12-2002', '05-01-2009', '28-09-2009', '15-06-2009', '22-07-2003', '30-03-2004', '20-07-2005', '01-08-2003', '28-11-2007', '18-06-2005', '09-12-2003', '14-02-2008', '18-07-2007', '28-12-2004', '19-06-2003', '22-04-2009', '03-01-2006', '31-08-2009', '29-07-2004', '25-09-2007', '12-05-2005', '01-12-2009', '18-05-2009', '22-05-2006', '14-12-2004', '29-12-2005', '29-08-2008', '07-04-2006', '13-08-2004', '11-08-2004', '04-01-2007', '06-06-2005', '23-12-2009', '10-10-2003', '20-05-2008', '04-08-2006', '23-07-2007', '05-10-2004', '17-01-2007', '14-07-2008', '06-01-2006', '26-11-2008', '18-04-2007', '01-02-2004', '11-04-2007', '27-05-2009', '05-08-2009', '24-07-2009', '23-07-2008', '06-06-2006', '02-11-2009', '18-11-2005', '25-08-2005', '29-01-2007', '04-10-2005', '19-07-2007', '08-01-2008', '15-06-2005', '01-12-2003', '29-08-2003', '08-11-2005', '13-01-2003', '14-07-2003', '05-10-2009', '25-05-2005', '01-12-2005', '12-06-2006', '30-11-2005', '07-06-2005', '07-03-2006', '29-03-2004', ' ...

# %% [markdown]
# ### Check Distribution of Numerical Columns

# %%
numerical_cols = [item for item in all_columns if item not in string_columns]
numerical_cols = [item for item in numerical_cols if item not in ['id']]

numerical_cols

for col in numerical_cols:
    distribution = df.select(col).describe()
    print(col)
    print(distribution, '\n\n')
