# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### Import Libraries

# %%
import sys
import polars as pl
import polars.selectors as pol_sel

# %% [markdown]
# ### Show Python & Library Versions

# %%
l = 8
r = 12

print("Python".rjust(l), ":", sys.version[0:6].ljust(r))
print("Polars".rjust(l), ":", pl.__version__.ljust(r))
# Out:
#   Python : 3.11.4
#   Polars : 1.12.0

# %% [markdown]
# ## Exploratory Data Analysis with Polars

# %% [markdown]
# ### Load CSV File into Polars DataFrame

# %%
df = pl.read_csv("../data/Insurance_Claim_Info_data.csv",
                 ignore_errors=True)

df
# Out:
# shape: (34_110, 7)
# ┌──────────────┬───────────┬───────────┬───────────────┬───────────────┬────────────┬──────────────┐
# │ Claim Number ┆ City Code ┆ City      ┆ Enterprise    ┆ Claim Type    ┆ Claim Site ┆ Product      │
# │ ---          ┆ ---       ┆ ---       ┆ Type          ┆ ---           ┆ ---        ┆ Insured      │
# │ str          ┆ str       ┆ str       ┆ ---           ┆ str           ┆ str        ┆ ---          │
# │              ┆           ┆           ┆ str           ┆               ┆            ┆ str          │
# ╞══════════════╪═══════════╪═══════════╪═══════════════╪═══════════════╪════════════╪══════════════╡
# │ DQW1NZO0PL   ┆ NSK       ┆ Nashik    ┆ Public        ┆ Property Loss ┆ In Transit ┆ Inventory -  │
# │              ┆           ┆           ┆ Limited       ┆               ┆            ┆ Raw Material │
# │              ┆           ┆           ┆ Company       ┆               ┆            ┆              │
# │ JS5GAPRN5B   ┆ BOM       ┆ Mumbai    ┆ One Person    ┆ Property Loss ┆ In Transit ┆ Cameras and  │
# │              ┆           ┆           ┆ Company       ┆               ┆            ┆ other Misc.  │
# │              ┆           ┆           ┆               ┆               ┆            ┆ Securi…      │
# │ ZTSVAQSEAQ   ┆ LKO       ┆ Lucknow   ┆ Public        ┆ Property Loss ┆ In Transit ┆ Fixtures     │
# │              ┆           ┆           ┆ Limited       ┆               ┆            ┆              │
# │              ┆           ┆           ┆ Company       ┆               ┆            ┆              │
# │ EW7NWHI7LI   ┆ DEL       ┆ Delhi     ┆ Sole Propriet ┆ Property Loss ┆ In Transit ┆ Pumps and    │
# │              ┆           ┆           ┆ orship        ┆               ┆            ┆ Motors       │
# │ UJOFDC41EL   ┆ DEL       ┆ Delhi     ┆ One Person    ┆ Property Loss ┆ In Transit ┆ Misc.        │
# │              ┆           ┆           ┆ Company       ┆               ┆            ┆ Engineering  │
# │              ┆           ┆           ┆               ┆               ┆            ┆ Tools        │
# │ …            ┆ …         ┆ …         ┆ …             ┆ …             ┆ …          ┆ …            │
# │ 5CFGWQ6IR5   ┆ AGR       ┆ Agra      ┆ Public        ┆ Property Loss ┆ In Transit ┆ Misc.        │
# │              ┆           ┆           ┆ Limited       ┆               ┆            ┆ Engineering  │
# │              ┆           ┆           ┆ Company       ┆               ┆            ┆ Tools        │
# │ QQ6EAWA4Q5   ┆ LKO       ┆ Lucknow   ┆ Partnership   ┆ Property      ┆ In Transit ┆ Misc.        │
# │              ┆           ┆           ┆ Firm          ┆ Damage        ┆            ┆ Electronic   │
# │              ┆           ┆           ┆               ┆               ┆            ┆ Items        │
# │ X1J58PT1J5   ┆ HYD       ┆ Hyderabad ┆ One Person    ┆ Property      ┆ In Transit ┆ Misc.        │
# │              ┆           ┆           ┆ Company       ┆ Damage        ┆            ┆ Electronic   │
# │              ┆           ┆           ┆               ┆               ┆            ┆ Items        │
# │ AGOXXE8KII   ┆ MAA       ┆ Chennai   ┆ Sole Propriet ┆ Property      ┆ Warehouse  ┆ Pumps and    │
# │              ┆           ┆           ┆ orship        ┆ Damage        ┆            ┆ Motors       │
# │ WT5RH23GPC   ┆ LKO       ┆ Lucknow   ┆ Private Ltd.  ┆ Property Loss ┆ In Transit ┆ Inventory -  │
# │              ┆           ┆           ┆ MSME - Medium ┆               ┆            ┆ Raw Material │
# └──────────────┴───────────┴───────────┴───────────────┴───────────────┴────────────┴──────────────┘

# %%
column_data_types = zip(df.columns, df.dtypes)

for column, dtype in column_data_types:
    print(f"{column}:\t\t{dtype}")
# Out:
# Claim Number:		String
# City Code:		String
# City:		String
# Enterprise Type:		String
# Claim Type:		String
# Claim Site:		String
# Product Insured:		String

# %% [markdown]
# ### Retrieve Basic Information About DataFrame

# %%
print(df.shape)
print(df.dtypes)
# Out:
# (34110, 7)
# [String, String, String, String, String, String, String]

# %% [markdown]
# ### Display Summary Statistics for All Columns

# %%
summary = df.describe()
print(summary)
# Out:
# shape: (9, 8)
# ┌────────────┬────────────┬───────────┬────────────┬───────────┬───────────┬───────────┬───────────┐
# │ statistic  ┆ Claim      ┆ City Code ┆ City       ┆ Enterpris ┆ Claim     ┆ Claim     ┆ Product   │
# │ ---        ┆ Number     ┆ ---       ┆ ---        ┆ e Type    ┆ Type      ┆ Site      ┆ Insured   │
# │ str        ┆ ---        ┆ str       ┆ str        ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │            ┆ str        ┆           ┆            ┆ str       ┆ str       ┆ str       ┆ str       │
# ╞════════════╪════════════╪═══════════╪════════════╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ count      ┆ 34110      ┆ 34110     ┆ 34110      ┆ 34110     ┆ 34110     ┆ 34110     ┆ 34110     │
# │ null_count ┆ 0          ┆ 0         ┆ 0          ┆ 0         ┆ 0         ┆ 0         ┆ 0         │
# │ mean       ┆ null       ┆ null      ┆ null       ┆ null      ┆ null      ┆ null      ┆ null      │
# │ std        ┆ null       ┆ null      ┆ null       ┆ null      ┆ null      ┆ null      ┆ null      │
# │ min        ┆ 000TQE7Z0O ┆ AGR       ┆ Agra       ┆ Cooperati ┆ Property  ┆ In        ┆ Cameras   │
# │            ┆            ┆           ┆            ┆ ve        ┆ Damage    ┆ Transit   ┆ and other │
# │            ┆            ┆           ┆            ┆ Society   ┆           ┆           ┆ Misc.     │
# │            ┆            ┆           ┆            ┆           ┆           ┆           ┆ Securi…   │
# │ 25%        ┆ null       ┆ null      ┆ null       ┆ null      ┆ null      ┆ null      ┆ null      │
# │ 50%        ┆ null       ┆ null      ┆ null       ┆ null      ┆ null      ┆ null      ┆ null      │
# │ 75%        ┆ null       ┆ null      ┆ null       ┆ null      ┆ null      ┆ null      ┆ null      │
# │ max        ┆ ZZW9JKTJMJ ┆ VSK       ┆ Visakhapat ┆ Sole Prop ┆ Property  ┆ Warehouse ┆ Pumps and │
# │            ┆            ┆           ┆ nam        ┆ rietorshi ┆ Loss      ┆           ┆ Motors    │
# │            ┆            ┆           ┆            ┆ p         ┆           ┆           ┆           │
# └────────────┴────────────┴───────────┴────────────┴───────────┴───────────┴───────────┴───────────┘

# %% [markdown]
# ### Count of Nulls In Each Feature

# %%
for col in df.columns:
    print(f"{col} : {df[col].is_null().sum()}")
# Out:
# Claim Number : 0
# City Code : 0
# City : 0
# Enterprise Type : 0
# Claim Type : 0
# Claim Site : 0
# Product Insured : 0

# %% [markdown]
# ### Find Longest Text Length in Each Column

# %%
# Create an empty list to store max lengths for each string column
longest_text_lengths = []

# Loop through the columns to check for string columns
string_columns = [col for col in df.columns if df[col].dtype == pl.Utf8]

max_lengths = {}
for col in string_columns:
    max_length = df.select(pl.col(col).str.len_chars().max()).to_numpy()[0, 0]
    max_lengths[col] = max_length

df_max_lengths = pl.DataFrame(max_lengths)

df_max_lengths
# Out:
# shape: (1, 7)
# ┌──────────────┬───────────┬──────┬─────────────────┬────────────┬────────────┬─────────────────┐
# │ Claim Number ┆ City Code ┆ City ┆ Enterprise Type ┆ Claim Type ┆ Claim Site ┆ Product Insured │
# │ ---          ┆ ---       ┆ ---  ┆ ---             ┆ ---        ┆ ---        ┆ ---             │
# │ u32          ┆ u32       ┆ u32  ┆ u32             ┆ u32        ┆ u32        ┆ u32             │
# ╞══════════════╪═══════════╪══════╪═════════════════╪════════════╪════════════╪═════════════════╡
# │ 10           ┆ 3         ┆ 13   ┆ 36              ┆ 15         ┆ 10         ┆ 56              │
# └──────────────┴───────────┴──────┴─────────────────┴────────────┴────────────┴─────────────────┘

# %% [markdown]
# ### Count Unique Values in Each Column

# %%
all_columns = [col for col in df.columns]

for col in all_columns:
    unique_counts = df[col].n_unique()
    print(f"Unique values in {col} :".rjust(48), f"{unique_counts}".ljust(6))
# Out:
#                  Unique values in Claim Number : 34110
#                     Unique values in City Code : 23
#                          Unique values in City : 23
#               Unique values in Enterprise Type : 13
#                    Unique values in Claim Type : 2
#                    Unique values in Claim Site : 3
#               Unique values in Product Insured : 13

# %% [markdown]
# ### Retrieve Unique Values in Each Feature

# %%
for col in df.columns:
    unique_values = df[col].unique()
    print(f"'{col}' {len(unique_values)}: {unique_values.to_list()}")
# Out:
# 'Claim Number' 34110: ['3OUDAT43HR', '27YLQOG7Y6', '3584EX9OWL', '30E35IBJPV', 'DWER9OVRFW', 'ZPLKLH8J45', 'CQSCBM05CU', 'BDKOSG4TC3', '8VC1K86MPL', 'FFUR60UJLJ', 'GGHO90XLPQ', 'OT005SJ8IB', 'V5JSJKQI5T', '5TU2NJCDSY', 'A6YPOTGOIB', 'FJLRF46FJY', 'MRS5TBK47E', '84RPVVT01D', 'AJDKVTGVDM', 'KEBYQO3I6W', 'TU5QJILEXW', 'RS7L4XWCO9', '76MAQSHYPT', 'QXGYH039OH', 'OFAKQEYCVR', '5C73C6G220', 'FJ0ZQG0WKQ', 'F6M2JUIIPV', '9XY7ND16TR', '3UDIFZ8DG9', 'JFHVQHFDU5', 'U2X7NXLQC3', 'NS96FD776F', '23QUVGBLFE', 'WYIETZB5K1', 'PBDTUV4M9H', '92J7GJO83L', 'IZ200FBCFV', 'EW7BQ5WSJA', 'S5H8ZETEGI', '52VTIQ5ZW7', 'VVAYEORAKW', 'RF8II9DH62', '14NDA33EH1', 'WNVBDPWJYL', 'P5Z8X40CI8', '8XAUP2DVHQ', '2LEDPABLWQ', 'W19JH18EV3', '3MKM67MV4V', 'X2ZNJRTSBV', 'D3LW02F6X9', 'KI8SRQ9T0C', 'HLH16V8MOZ', 'S7O4MM5BT1', '7LA1X2UFQ7', 'N7NG2ZL8XM', 'ITHT79ROM4', 'IK9E4RKCDR', 'UI1MWHU3CP', '7EDYL093ER', 'U0L6QMZAZ9', 'O905SHZFSQ', '32URG9SC66', 'JMHVRB13MD', 'GQL8QK3HLY', 'OWB1Z7HZDS', 'BFTOFHVRB2', 'QRZEBB5H5O', 'XIVS31G877', 'Z9DQBE70GT', '6O287H5M3Y', 'Z23ZM5SB21', 'P77EDS1REV', '8AK4P1GR5D', 'ECMYOQ6XU1', 'DSILIU4EV9', 'RBEL3Y99XV', 'OPD6PETBI2', 'T1PEVDDRJK', 'L5DIPCSBI7', 'CBKXVRI0WI', 'BIY2MFTNAO', 'WTLTOH83G4', '7K9QZF6O3A', 'S6QX9WDHF8', '82U43OHITF', '6QG5D2DT4W', 'UYP8QTZGVQ', '1DZHNWXOBN', '14GP0IBFIV', '6FXLSICQLD', 'R013GFBZXA', 'V29EE95O2J', 'LUFL2S7ZCI', 'C5HJGJ3DE6', 'JNVZJUZIBI', '0PXMREZ5WM', '47OS73SN77', 'LTVKY8HNUT', 'VI7BVDA1TC', 'AVINUN1UC9', 'Y39ONBZZUV', '8C9NNER7QN', 'Z27OOC07EM', 'RODRMXFP8S', 'H9VCR2VHNA', 'A7OGTMYFRR', 'GJ15KD2ZG8', 'GV0LRI0H0T', 'NUACJKUFVM', 'S4BKXWRMED', 'XY3E0GJBID', 'DOTBERDZVP', 'U84GS93YF2', 'AB5TC60CGU', 'V60SSR67JQ', 'ZYD1JPYIKN', '1DFL0RIBN1', '3JF5SFW0G8', 'RXBRBPR7T1', '9IAFPBTCPW', '0B520CL5BV', 'NAEM8BLNBA', '8SWYS5YAQT', '100QV999LT', 'FW0UDSOV1X', 'U6DDJOPTUR', 'J88NC2WZOE', 'VBR3ZTKZBY', '4XLTPL4K3N', '55BJIUMFFJ', 'WCWUFSDJP5', 'LFHW7LYE3C', 'Z8WFKMNY4N', 'CLF77CI6II', '8TBKU0KW24', 'K2OQDVVPFM', 'DJZMT7QP4N', 'II1O0SKNBX', 'YFLBI93933', 'QF6M2SXC7E', '89E9CW1Q0V', 'HX2LBWGHLS', '7VH6ZVF4U7', 'FED4I4WOFY', 'Z2RJEEJ7PB', 'FS4365O5DW', '7TXNJ7LD0R', 'MYLQCFNDAI', '7NT5L80D2I', '2RJ7BS1THL', 'ZEA3OAAP07', 'L0CL1YJRHQ', 'C2YBZZC9HN', '4DKYKK0A2U', 'TO6F9MFXNL', 'IAS8AM2IZW', 'P1B9ZNMLLO', '5OJLKW40RB', 'K9W56RGAH8', 'ZG2YXJGNM1', 'KYH24G88FG', '3SBROSF3ON', '09490WVECK', '93MII0WJO6', 'DYRR8UGUPC', 'THE6WV7MHR', 'TZE89S6NNS', '09IGIZP1NZ', 'F0PCRE3DEG', 'VI542I6NID', 'OXYQYGD0AR', 'FMZ7J36IXG', 'MUV0DOJITI', 'ID8GGIE54S', 'AWX8KIWDWD', '3XCMCZFRRK', '6XYHBL0ETY', 'Q0ZNF5Q1CK', 'SCN2N5IGZ5', 'O8I24QNAWZ', '03LKY7ZNDG', 'YVVO7GPOJK', '3ZVPNP48HK', 'OF5GLUVTVJ', '9L2BZE9U47', 'M4LR72WT5C', '7833NIG3W5', 'A1ZSIJKQ6F', 'RINBEJDBBC', '9EPO5S1MJY', 'D3RQ7JL6I6', 'M2U0A4MYF0', 'FVGH875EXZ', 'SP02DAXSIQ', 'AUXX8GTCAZ', '31GP1T64GB', 'KM3YX5J9E9', 'V0GWAE7GVK', 'ZEHS37XFBM', 'AQWS7J3L0S', 'EU081XLTX0', 'GBAT81NDAV', '5KKVEVUW9C', 'QHZGPCY3HD', 'IAYXRWMNGB', '6FXF7WX8Y2', 'AWXZ0TAX44', 'BROOCSKGWW', 'JSX85783YR', 'ZWXUSSE4O5', 'W23FHWV0GT', '5GJYH4PJQL', 'QV4XSPNBX4', 'S0VHH36LS4', 'ECG1TNXB41', '060SXGO7FL', '12DN3KK9CH', 'G3DYOXEBFC', '9J8RU9KPTF', 'T4UTWATCCM', 'J1PVC38WLT', 'YBVMDVHCY6', '6UR9YG7WPM', 'OXLCBP5AP9', 'IW8M2DC059', '0F3B3MJURJ', 'PJNJNGKBHV', 'RLD4EWC6PX', 'JCC9OL5ML7', 'CZMJVC8LI0', 'PNYWBJVLMO', 'JC52LXK4G7', 'UIH7TPW21D', 'SBZ922ZQ0R', 'V6ZRV9AOHX', 'O1GJHG8WDD', 'TZ92PZUP6O', '7DO7U9CI23', '2F00LAF9JB', 'HRWV9FKA06', '1CFL9Z86H6', 'NYQC3NII61', '9HV9HC7HAD', 'QNYII571VQ', '9HZS7N740K', 'SGLZQ0FOOZ', 'JMUSVHBF2P', 'N0HZ6R9XZ7', '1JMI0EJHMY', '43GHETWL4E', '7TWCXI3U9L', 'V64SULNXYL', 'OGN8LEELWL', 'FA4P7JLXKL', '7H3BEGWDPI', 'G8850SAWX6', 'HP7QP65D1Q', 'E2O2CNVTYT', 'UE2PEFK6V9', '9384NCGQHH', 'YDQDM6THCS', 'O7FKMC87P6', 'O7RERJ5564', 'MNX0MRCKB9', 'ECD0EBMH9O', 'M0OASR8X5L', 'TLMPKNMXSA', 'BDFOLJHCFE', 'LGWNKQSWZ2', 'B04G32YELY', 'L8NU6M5FQG', 'LUW0KCZC8Q', '300YE1I5VN', '3DC5QARW4C', '9RA423YKU6', '8A188ZR6KS', '2ORGIWQY94', '2NIULEV0FN', 'NG6ROH73W1', 'VE1O0EHHPO', 'B8JAZVRR2W', 'J5C6JAY6U7', ' ...
# 'City Code' 23: ['ATQ', 'PNQ', 'NSK', 'NGP', 'MAA', 'BHO', 'AMD', 'KNU', 'PAT', 'CJB', 'DEL', 'BLR', 'THN', 'BOM', 'JAI', 'HYD', 'AGR', 'STV', 'IDR', 'BDQ', 'VSK', 'LKO', 'CCU']
# 'City' 23: ['Nagpur', 'Jaipur', 'Hyderabad', 'Bhopal', 'Ahmedabad', 'Kanpur', 'Agra', 'Amritsar', 'Vadodara', 'Patna', 'Coimbatore', 'Kolkata', 'Surat', 'Lucknow', 'Thane', 'Delhi', 'Mumbai', 'Chennai', 'Visakhapatnam', 'Pune', 'Nashik', 'Bangalore', 'Indore']
# 'Enterprise Type' 13: ['Cooperative Society', 'Partnership Firm', 'Non-Profit Organization (NPO)', 'Public Limited Company', 'Sole Proprietorship', 'Private Ltd. MSME - Medium', 'Private Ltd. MSME - Micro', 'Private Limited Company', 'Private Ltd. MSME - Small', 'One Person Company', 'Limited Liability Parterneship (LLP)', 'Foreign Subsidary', 'Joint-Venture Company']
# 'Claim Type' 2: ['Property Loss', 'Property Damage']
# 'Claim Site' 3: ['In Transit', 'Warehouse', 'Other']
# 'Product Insured' 13: ['Cameras and other Misc. Security Equipment', 'Fixtures', 'Misc. Sensors', 'Misc. Electrical Equipment', 'Property, Plant, and Equipment (PPE) Parts', 'Furniture', 'Inventory - Finished Goods', 'Misc. Electronic Items', 'Heating, ventilation, and air conditioning (HVAC) System', 'Pumps and Motors', 'Misc. Engineering Tools', 'Inventory - Raw Material', 'Misc. Lab Equipment']
