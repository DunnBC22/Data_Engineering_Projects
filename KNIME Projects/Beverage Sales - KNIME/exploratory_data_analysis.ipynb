# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### Import Libraries

# %%
import sys
import polars as pl
import polars.selectors as pol_sel

# %% [markdown]
# ### Show Python & Library Versions

# %%
l = 8
r = 12

print("Python".rjust(l), ":", sys.version[0:6].ljust(r))
print("Polars".rjust(l), ":", pl.__version__.ljust(r))
# Out:
#   Python : 3.11.4
#   Polars : 1.12.0

# %% [markdown]
# ### Load CSV File into Polars DataFrame

# %%
df = pl.read_csv("data/data.csv")

df
# Out:
# shape: (8_999_910, 11)
# ┌───────────┬───────────┬───────────┬───────────┬───┬──────────┬───────────┬───────────┬───────────┐
# │ Order_ID  ┆ Customer_ ┆ Customer_ ┆ Product   ┆ … ┆ Discount ┆ Total_Pri ┆ Region    ┆ Order_Dat │
# │ ---       ┆ ID        ┆ Type      ┆ ---       ┆   ┆ ---      ┆ ce        ┆ ---       ┆ e         │
# │ str       ┆ ---       ┆ ---       ┆ str       ┆   ┆ f64      ┆ ---       ┆ str       ┆ ---       │
# │           ┆ str       ┆ str       ┆           ┆   ┆          ┆ f64       ┆           ┆ str       │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪══════════╪═══════════╪═══════════╪═══════════╡
# │ ORD1      ┆ CUS1496   ┆ B2B       ┆ Vio       ┆ … ┆ 0.1      ┆ 79.18     ┆ Baden-Wür ┆ 2023-08-2 │
# │           ┆           ┆           ┆ Wasser    ┆   ┆          ┆           ┆ ttemberg  ┆ 3         │
# │ ORD1      ┆ CUS1496   ┆ B2B       ┆ Evian     ┆ … ┆ 0.1      ┆ 126.36    ┆ Baden-Wür ┆ 2023-08-2 │
# │           ┆           ┆           ┆           ┆   ┆          ┆           ┆ ttemberg  ┆ 3         │
# │ ORD1      ┆ CUS1496   ┆ B2B       ┆ Sprite    ┆ … ┆ 0.05     ┆ 81.14     ┆ Baden-Wür ┆ 2023-08-2 │
# │           ┆           ┆           ┆           ┆   ┆          ┆           ┆ ttemberg  ┆ 3         │
# │ ORD1      ┆ CUS1496   ┆ B2B       ┆ Rauch Mul ┆ … ┆ 0.1      ┆ 170.98    ┆ Baden-Wür ┆ 2023-08-2 │
# │           ┆           ┆           ┆ tivitamin ┆   ┆          ┆           ┆ ttemberg  ┆ 3         │
# │ ORD1      ┆ CUS1496   ┆ B2B       ┆ Gerolstei ┆ … ┆ 0.1      ┆ 27.4      ┆ Baden-Wür ┆ 2023-08-2 │
# │           ┆           ┆           ┆ ner       ┆   ┆          ┆           ┆ ttemberg  ┆ 3         │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …        ┆ …         ┆ …         ┆ …         │
# │ ORD299999 ┆ CUS7080   ┆ B2C       ┆ Schwip    ┆ … ┆ 0.0      ┆ 2.54      ┆ Sachsen   ┆ 2023-07-0 │
# │ 9         ┆           ┆           ┆ Schwap    ┆   ┆          ┆           ┆           ┆ 3         │
# │ ORD299999 ┆ CUS7080   ┆ B2C       ┆ San Pelle ┆ … ┆ 0.0      ┆ 13.65     ┆ Sachsen   ┆ 2023-07-0 │
# │ 9         ┆           ┆           ┆ grino     ┆   ┆          ┆           ┆           ┆ 3         │
# │ ORD300000 ┆ CUS6551   ┆ B2B       ┆ Red Bull  ┆ … ┆ 0.1      ┆ 169.34    ┆ Sachsen-A ┆ 2022-04-0 │
# │ 0         ┆           ┆           ┆           ┆   ┆          ┆           ┆ nhalt     ┆ 9         │
# │ ORD300000 ┆ CUS6551   ┆ B2B       ┆ Passion   ┆ … ┆ 0.1      ┆ 287.24    ┆ Sachsen-A ┆ 2022-04-0 │
# │ 0         ┆           ┆           ┆ Fruit     ┆   ┆          ┆           ┆ nhalt     ┆ 9         │
# │           ┆           ┆           ┆ Juice     ┆   ┆          ┆           ┆           ┆           │
# │ ORD300000 ┆ CUS6551   ┆ B2B       ┆ Vittel    ┆ … ┆ 0.1      ┆ 3.08      ┆ Sachsen-A ┆ 2022-04-0 │
# │ 0         ┆           ┆           ┆           ┆   ┆          ┆           ┆ nhalt     ┆ 9         │
# └───────────┴───────────┴───────────┴───────────┴───┴──────────┴───────────┴───────────┴───────────┘

# %% [markdown]
# ### Display First Few Rows to Understand Structure of Data

# %%
print(df.head())
# Out:
# shape: (5, 11)
# ┌──────────┬────────────┬───────────┬───────────┬───┬──────────┬───────────┬───────────┬───────────┐
# │ Order_ID ┆ Customer_I ┆ Customer_ ┆ Product   ┆ … ┆ Discount ┆ Total_Pri ┆ Region    ┆ Order_Dat │
# │ ---      ┆ D          ┆ Type      ┆ ---       ┆   ┆ ---      ┆ ce        ┆ ---       ┆ e         │
# │ str      ┆ ---        ┆ ---       ┆ str       ┆   ┆ f64      ┆ ---       ┆ str       ┆ ---       │
# │          ┆ str        ┆ str       ┆           ┆   ┆          ┆ f64       ┆           ┆ str       │
# ╞══════════╪════════════╪═══════════╪═══════════╪═══╪══════════╪═══════════╪═══════════╪═══════════╡
# │ ORD1     ┆ CUS1496    ┆ B2B       ┆ Vio       ┆ … ┆ 0.1      ┆ 79.18     ┆ Baden-Wür ┆ 2023-08-2 │
# │          ┆            ┆           ┆ Wasser    ┆   ┆          ┆           ┆ ttemberg  ┆ 3         │
# │ ORD1     ┆ CUS1496    ┆ B2B       ┆ Evian     ┆ … ┆ 0.1      ┆ 126.36    ┆ Baden-Wür ┆ 2023-08-2 │
# │          ┆            ┆           ┆           ┆   ┆          ┆           ┆ ttemberg  ┆ 3         │
# │ ORD1     ┆ CUS1496    ┆ B2B       ┆ Sprite    ┆ … ┆ 0.05     ┆ 81.14     ┆ Baden-Wür ┆ 2023-08-2 │
# │          ┆            ┆           ┆           ┆   ┆          ┆           ┆ ttemberg  ┆ 3         │
# │ ORD1     ┆ CUS1496    ┆ B2B       ┆ Rauch Mul ┆ … ┆ 0.1      ┆ 170.98    ┆ Baden-Wür ┆ 2023-08-2 │
# │          ┆            ┆           ┆ tivitamin ┆   ┆          ┆           ┆ ttemberg  ┆ 3         │
# │ ORD1     ┆ CUS1496    ┆ B2B       ┆ Gerolstei ┆ … ┆ 0.1      ┆ 27.4      ┆ Baden-Wür ┆ 2023-08-2 │
# │          ┆            ┆           ┆ ner       ┆   ┆          ┆           ┆ ttemberg  ┆ 3         │
# └──────────┴────────────┴───────────┴───────────┴───┴──────────┴───────────┴───────────┴───────────┘

# %% [markdown]
# ### Retrieve Basic Information About DataFrame

# %%
print(df.shape)
print(df.dtypes)
# Out:
# (8999910, 11)
# [String, String, String, String, String, Float64, Int64, Float64, Float64, String, String]

# %% [markdown]
# ### Display Summary Statistics for All Columns

# %%
summary = df.describe()
print(summary)
# Out:
# shape: (9, 12)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ statistic ┆ Order_ID  ┆ Customer_ ┆ Customer_ ┆ … ┆ Discount  ┆ Total_Pri ┆ Region    ┆ Order_Da │
# │ ---       ┆ ---       ┆ ID        ┆ Type      ┆   ┆ ---       ┆ ce        ┆ ---       ┆ te       │
# │ str       ┆ str       ┆ ---       ┆ ---       ┆   ┆ f64       ┆ ---       ┆ str       ┆ ---      │
# │           ┆           ┆ str       ┆ str       ┆   ┆           ┆ f64       ┆           ┆ str      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ count     ┆ 8999910   ┆ 8999910   ┆ 8999910   ┆ … ┆ 8.99991e6 ┆ 8.99991e6 ┆ 8999910   ┆ 8999910  │
# │ null_coun ┆ 0         ┆ 0         ┆ 0         ┆ … ┆ 0.0       ┆ 0.0       ┆ 0         ┆ 0        │
# │ t         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ mean      ┆ null      ┆ null      ┆ null      ┆ … ┆ 0.029729  ┆ 130.74365 ┆ null      ┆ null     │
# │           ┆           ┆           ┆           ┆   ┆           ┆ 9         ┆           ┆          │
# │ std       ┆ null      ┆ null      ┆ null      ┆ … ┆ 0.044798  ┆ 509.69474 ┆ null      ┆ null     │
# │           ┆           ┆           ┆           ┆   ┆           ┆ 3         ┆           ┆          │
# │ min       ┆ ORD1      ┆ CUS1      ┆ B2B       ┆ … ┆ 0.0       ┆ 0.3       ┆ Baden-Wür ┆ 2021-01- │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ ttemberg  ┆ 01       │
# │ 25%       ┆ null      ┆ null      ┆ null      ┆ … ┆ 0.0       ┆ 8.4       ┆ null      ┆ null     │
# │ 50%       ┆ null      ┆ null      ┆ null      ┆ … ┆ 0.0       ┆ 21.14     ┆ null      ┆ null     │
# │ 75%       ┆ null      ┆ null      ┆ null      ┆ … ┆ 0.05      ┆ 69.49     ┆ null      ┆ null     │
# │ max       ┆ ORD999999 ┆ CUS9999   ┆ B2C       ┆ … ┆ 0.15      ┆ 14295.3   ┆ Thüringen ┆ 2023-12- │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ 30       │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %% [markdown]
# ### Find Longest Text Length in Each Column

# %%
# Create an empty list to store max lengths for each string column
longest_text_lengths = []

# Loop through the columns to check for string columns
string_columns = [col for col in df.columns if df[col].dtype == pl.Utf8]

max_lengths = {}
for col in string_columns:
    max_length = df.select(pl.col(col).str.len_chars().max()).to_numpy()[0, 0]
    max_lengths[col] = max_length

df_max_lengths = pl.DataFrame(max_lengths)

df_max_lengths
# Out:
# shape: (1, 7)
# ┌──────────┬─────────────┬───────────────┬─────────┬──────────┬────────┬────────────┐
# │ Order_ID ┆ Customer_ID ┆ Customer_Type ┆ Product ┆ Category ┆ Region ┆ Order_Date │
# │ ---      ┆ ---         ┆ ---           ┆ ---     ┆ ---      ┆ ---    ┆ ---        │
# │ u32      ┆ u32         ┆ u32           ┆ u32     ┆ u32      ┆ u32    ┆ u32        │
# ╞══════════╪═════════════╪═══════════════╪═════════╪══════════╪════════╪════════════╡
# │ 10       ┆ 8           ┆ 3             ┆ 19      ┆ 19       ┆ 22     ┆ 10         │
# └──────────┴─────────────┴───────────────┴─────────┴──────────┴────────┴────────────┘

# %% [markdown]
# ### Retrieve Data Types of All Columns

# %%
print("Column data types:\n", df.dtypes)
# Out:
# Column data types:
#  [String, String, String, String, String, Float64, Int64, Float64, Float64, String, String]

# %% [markdown]
# ### Count Unique Values in Each Column

# %%
all_columns = [col for col in df.columns]

for col in all_columns:
    unique_counts = df[col].n_unique()
    print(f"Unique values in {col} :".rjust(48), f"{unique_counts}".ljust(6))
# Out:
#                      Unique values in Order_ID : 3000000
#                   Unique values in Customer_ID : 10000
#                 Unique values in Customer_Type : 2
#                       Unique values in Product : 47
#                      Unique values in Category : 4
#                    Unique values in Unit_Price : 12778
#                      Unique values in Quantity : 100
#                      Unique values in Discount : 4
#                   Unique values in Total_Price : 203842
#                        Unique values in Region : 16
#                    Unique values in Order_Date : 1094

# %% [markdown]
# ### Check Distribution of Numerical Columns

# %%
numerical_cols = [item for item in all_columns if item not in string_columns]
numerical_cols = [item for item in numerical_cols if item not in ['id']]

numerical_cols

for col in numerical_cols:
    distribution = df.select(col).describe()
    print(col)
    print(distribution, '\n\n')
# Out:
# Unit_Price
# shape: (9, 2)
# ┌────────────┬────────────┐
# │ statistic  ┆ Unit_Price │
# │ ---        ┆ ---        │
# │ str        ┆ f64        │
# ╞════════════╪════════════╡
# │ count      ┆ 8.99991e6  │
# │ null_count ┆ 0.0        │
# │ mean       ┆ 5.818037   │
# │ std        ┆ 14.700501  │
# │ min        ┆ 0.32       │
# │ 25%        ┆ 1.05       │
# │ 50%        ┆ 1.75       │
# │ 75%        ┆ 3.21       │
# │ max        ┆ 169.53     │
# └────────────┴────────────┘
#
#
# Quantity
# shape: (9, 2)
# ┌────────────┬───────────┐
# │ statistic  ┆ Quantity  │
# │ ---        ┆ ---       │
# │ str        ┆ f64       │
# ╞════════════╪═══════════╡
# │ count      ┆ 8.99991e6 │
# │ null_count ┆ 0.0       │
# │ mean       ┆ 23.138134 │
# │ std        ┆ 26.893207 │
# │ min        ┆ 1.0       │
# │ 25%        ┆ 6.0       │
# │ 50%        ┆ 11.0      │
# │ 75%        ┆ 30.0      │
# │ max        ┆ 100.0     │
# └────────────┴───────────┘
#
#
# Discount
# shape: (9, 2)
# ┌────────────┬───────────┐
# │ statistic  ┆ Discount  │
# │ ---        ┆ ---       │
# │ str        ┆ f64       │
# ╞════════════╪═══════════╡
# │ count      ┆ 8.99991e6 │
# │ null_count ┆ 0.0       │
# │ mean       ┆ 0.029729  │
# │ std        ┆ 0.044798  │
# │ min        ┆ 0.0       │
# │ 25%        ┆ 0.0       │
# │ 50%        ┆ 0.0       │
# │ 75%        ┆ 0.05      │
# │ max        ┆ 0.15      │
# └────────────┴───────────┘
#
#
# Total_Price
# shape: (9, 2)
# ┌────────────┬─────────────┐
# │ statistic  ┆ Total_Price │
# │ ---        ┆ ---         │
# │ str        ┆ f64         │
# ╞════════════╪═════════════╡
# │ count      ┆ 8.99991e6   │
# │ null_count ┆ 0.0         │
# │ mean       ┆ 130.743659  │
# │ std        ┆ 509.694743  │
# │ min        ┆ 0.3         │
# │ 25%        ┆ 8.4         │
# │ 50%        ┆ 21.14       │
# │ 75%        ┆ 69.49       │
# │ max        ┆ 14295.3     │
# └────────────┴─────────────┘

# %% [markdown]
# ### Retrieve Unique Values for Specific Columns

# %%
cols_to_check = ['Order_Date']

for col in cols_to_check:
    unique_values = df[col].unique().sort().to_list()
    print(f"Column: {col}")
    print(f"Unique values: {unique_values}\n")
# Out:
# Column: Order_Date
# Unique values: ['2021-01-01', '2021-01-02', '2021-01-03', '2021-01-04', '2021-01-05', '2021-01-06', '2021-01-07', '2021-01-08', '2021-01-09', '2021-01-10', '2021-01-11', '2021-01-12', '2021-01-13', '2021-01-14', '2021-01-15', '2021-01-16', '2021-01-17', '2021-01-18', '2021-01-19', '2021-01-20', '2021-01-21', '2021-01-22', '2021-01-23', '2021-01-24', '2021-01-25', '2021-01-26', '2021-01-27', '2021-01-28', '2021-01-29', '2021-01-30', '2021-01-31', '2021-02-01', '2021-02-02', '2021-02-03', '2021-02-04', '2021-02-05', '2021-02-06', '2021-02-07', '2021-02-08', '2021-02-09', '2021-02-10', '2021-02-11', '2021-02-12', '2021-02-13', '2021-02-14', '2021-02-15', '2021-02-16', '2021-02-17', '2021-02-18', '2021-02-19', '2021-02-20', '2021-02-21', '2021-02-22', '2021-02-23', '2021-02-24', '2021-02-25', '2021-02-26', '2021-02-27', '2021-02-28', '2021-03-01', '2021-03-02', '2021-03-03', '2021-03-04', '2021-03-05', '2021-03-06', '2021-03-07', '2021-03-08', '2021-03-09', '2021-03-10', '2021-03-11', '2021-03-12', '2021-03-13', '2021-03-14', '2021-03-15', '2021-03-16', '2021-03-17', '2021-03-18', '2021-03-19', '2021-03-20', '2021-03-21', '2021-03-22', '2021-03-23', '2021-03-24', '2021-03-25', '2021-03-26', '2021-03-27', '2021-03-28', '2021-03-29', '2021-03-30', '2021-03-31', '2021-04-01', '2021-04-02', '2021-04-03', '2021-04-04', '2021-04-05', '2021-04-06', '2021-04-07', '2021-04-08', '2021-04-09', '2021-04-10', '2021-04-11', '2021-04-12', '2021-04-13', '2021-04-14', '2021-04-15', '2021-04-16', '2021-04-17', '2021-04-18', '2021-04-19', '2021-04-20', '2021-04-21', '2021-04-22', '2021-04-23', '2021-04-24', '2021-04-25', '2021-04-26', '2021-04-27', '2021-04-28', '2021-04-29', '2021-04-30', '2021-05-01', '2021-05-02', '2021-05-03', '2021-05-04', '2021-05-05', '2021-05-06', '2021-05-07', '2021-05-08', '2021-05-09', '2021-05-10', '2021-05-11', '2021-05-12', '2021-05-13', '2021-05-14', '2021-05-15', '2021-05-16', '2021-05-17', '2021-05-18', '2021-05-19', '2021-05-20', '2021-05-21', '2021-05-22', '2021-05-23', '2021-05-24', '2021-05-25', '2021-05-26', '2021-05-27', '2021-05-28', '2021-05-29', '2021-05-30', '2021-05-31', '2021-06-01', '2021-06-02', '2021-06-03', '2021-06-04', '2021-06-05', '2021-06-06', '2021-06-07', '2021-06-08', '2021-06-09', '2021-06-10', '2021-06-11', '2021-06-12', '2021-06-13', '2021-06-14', '2021-06-15', '2021-06-16', '2021-06-17', '2021-06-18', '2021-06-19', '2021-06-20', '2021-06-21', '2021-06-22', '2021-06-23', '2021-06-24', '2021-06-25', '2021-06-26', '2021-06-27', '2021-06-28', '2021-06-29', '2021-06-30', '2021-07-01', '2021-07-02', '2021-07-03', '2021-07-04', '2021-07-05', '2021-07-06', '2021-07-07', '2021-07-08', '2021-07-09', '2021-07-10', '2021-07-11', '2021-07-12', '2021-07-13', '2021-07-14', '2021-07-15', '2021-07-16', '2021-07-17', '2021-07-18', '2021-07-19', '2021-07-20', '2021-07-21', '2021-07-22', '2021-07-23', '2021-07-24', '2021-07-25', '2021-07-26', '2021-07-27', '2021-07-28', '2021-07-29', '2021-07-30', '2021-07-31', '2021-08-01', '2021-08-02', '2021-08-03', '2021-08-04', '2021-08-05', '2021-08-06', '2021-08-07', '2021-08-08', '2021-08-09', '2021-08-10', '2021-08-11', '2021-08-12', '2021-08-13', '2021-08-14', '2021-08-15', '2021-08-16', '2021-08-17', '2021-08-18', '2021-08-19', '2021-08-20', '2021-08-21', '2021-08-22', '2021-08-23', '2021-08-24', '2021-08-25', '2021-08-26', '2021-08-27', '2021-08-28', '2021-08-29', '2021-08-30', '2021-08-31', '2021-09-01', '2021-09-02', '2021-09-03', '2021-09-04', '2021-09-05', '2021-09-06', '2021-09-07', '2021-09-08', '2021-09-09', '2021-09-10', '2021-09-11', '2021-09-12', '2021-09-13', '2021-09-14', '2021-09-15', '2021-09-16', '2021-09-17', '2021-09-18', '2021-09-19', '2021-09-20', '2021-09-21', '2021-09-22', '2021-09-23', '2021-09-24', '2021-09-25', '2021-09-26', '2021-09-27', '2021-09-28', '2021-09-29', '2021-09-30', '2021-10-01', '2021-10-02', '2021-10-03', '2021-10-04', '2021-10-05', '2021-10-06', '2021-10-07', '2021-10-08', '2021-10-09', '2021-10-10', '2021-10-11', '2021-10 ...
