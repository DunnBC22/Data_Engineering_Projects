# %%
import pandas as pd

# %%
df = pd.read_csv(
    "../data/data.csv", 
    engine='c'
    )

df
# Out:
# /var/folders/93/v_c2ph_17t97zdkzc4_ccjtw0000gn/T/ipykernel_18002/1482257344.py:1: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(
#        date_received                                            product  \
# 0         2019-06-13  Credit reporting, credit repair services, or o...
# 1         2019-11-01                              Vehicle loan or lease
# 2         2019-04-01  Credit reporting, credit repair services, or o...
# 3         2019-04-10                        Credit card or prepaid card
# 4         2020-04-21  Credit reporting, credit repair services, or o...
# ...              ...                                                ...
# 170124    2020-09-18  Credit reporting, credit repair services, or o...
# 170125    2020-07-07  Money transfer, virtual currency, or money ser...
# 170126    2021-09-20  Credit reporting, credit repair services, or o...
# 170127    2019-12-02                                    Debt collection
# 170128    2020-04-25                                    Debt collection
#
#                      sub_product  \
# 0               Credit reporting
# 1                           Loan
# 2               Credit reporting
# 3              Store credit card
# 4               Credit reporting
# ...                          ...
# 170124          Credit reporting
# 170125  Mobile or digital wallet
# 170126          Credit reporting
# 170127             I do not know
# 170128             I do not know
#
#                                                     issue  \
# 0                    Incorrect information on your report
# 1                             Struggling to pay your loan
# 2                    Incorrect information on your report
# 3                                    Closing your account
# 4                    Incorrect information on your report
# ...                                                   ...
# 170124               Incorrect information on your report
# 170125  Unauthorized transactions or other transaction...
# 170126  Problem with a credit reporting company's inve...
# 170127                  Attempts to collect debt not owed
# 170128                  Attempts to collect debt not owed
#
#                                                 sub_issue  \
# 0                     Information belongs to someone else
# 1                        Denied request to lower payments
# 2                                Account status incorrect
# 3                               Can\'t close your account
# 4                           Account information incorrect
# ...                                                   ...
# 170124                Information belongs to someone else
# 170125                                                NaN
# 170126  Their investigation did not fix an error on yo...
# 170127                                  Debt is not yours
# 170128                                  Debt is not yours
#
#                              consumer_complaint_narrative  \
# 0                                                     NaN
# 1       I contacted Ally on Friday XX/XX/XXXX after fa...
# 2                                                     NaN
# 3                                                     NaN
# 4       Capital One Auto Finance incorrectly and witho...
# ...                                                   ...
# 170124                                                NaN
# 170125                                                NaN
# 170126                                                NaN
# 170127  This company appeared on my credit report out ...
# 170128                                                NaN
#
#                                   company_public_response  \
# 0                                                     NaN
# 1       Company has responded to the consumer and the ...
# 2       Company has responded to the consumer and the ...
# 3       Company believes it acted appropriately as aut...
# 4                                                     NaN
# ...                                                   ...
# 170124                                                NaN
# 170125                                                NaN
# 170126                                                NaN
# 170127                                                NaN
# 170128                                                NaN
#
#                                        company state_name zip_code  \
# 0            CAPITAL ONE FINANCIAL CORPORATION         PA  18640.0
# 1                          ALLY FINANCIAL INC.         NJ   8854.0
# 2       TRANSUNION INTERMEDIATE HOLDINGS, INC.         PA  19067.0
# 3              Atlanticus Services Corporation         WI  54409.0
# 4            CAPITAL ONE FINANCIAL CORPORATION         GA  30024.0
# ...                                        ...        ...      ...
# 170124                           EQUIFAX, INC.         CA  95136.0
# 170125                             Square Inc.        NaN      NaN
# 170126                           EQUIFAX, INC.         PA  15601.0
# 170127    Synerprise Consulting Services, Inc.         MO  63137.0
# 170128      Credit Systems International, Inc.         TX  77433.0
#
#                   tags consumer_consent_provided submitted_via  \
# 0                  NaN      Consent not provided           Web
# 1                  NaN          Consent provided           Web
# 2                  NaN      Consent not provided           Web
# 3       Older American                       NaN      Referral
# 4                  NaN          Consent provided           Web
# ...                ...                       ...           ...
# 170124             NaN      Consent not provided           Web
# 170125             NaN                       NaN         Phone
# 170126             NaN                     Other           Web
# 170127             NaN          Consent provided           Web
# 170128             NaN      Consent not provided           Web
#
#        date_sent_to_company company_response_to_consumer timely_response  \
# 0                2019-06-13      Closed with explanation             Yes
# 1                2019-11-01      Closed with explanation             Yes
# 2                2019-04-01      Closed with explanation             Yes
# 3                2019-04-16      Closed with explanation              No
# 4                2020-04-21      Closed with explanation             Yes
# ...                     ...                          ...             ...
# 170124           2020-10-05      Closed with explanation             Yes
# 170125           2020-07-07      Closed with explanation             Yes
# 170126           2021-09-20      Closed with explanation             Yes
# 170127           2019-12-02      Closed with explanation             Yes
# 170128           2020-04-25      Closed with explanation             Yes
#
#        consumer_disputed  complaint_id
# 0                    NaN       3274605
# 1                    NaN       3425257
# 2                    NaN       3198225
# 3                    NaN       3207424
# 4                    NaN       3616748
# ...                  ...           ...
# 170124               NaN       3854875
# 170125               NaN       3733003
# 170126               NaN       4735927
# 170127               NaN       3454681
# 170128               NaN       3622953
#
# [170129 rows x 18 columns]

# %%
df.describe(include='all')
# Out:
#        date_received                                            product  \
# count         170129                                             170129
# unique          2525                                                 17
# top       2021-06-09  Credit reporting, credit repair services, or o...
# freq             970                                              89652
# mean             NaN                                                NaN
# std              NaN                                                NaN
# min              NaN                                                NaN
# 25%              NaN                                                NaN
# 50%              NaN                                                NaN
# 75%              NaN                                                NaN
# max              NaN                                                NaN
#
#              sub_product                                 issue  \
# count             169840                                170129
# unique                67                                   143
# top     Credit reporting  Incorrect information on your report
# freq               88443                                 56139
# mean                 NaN                                   NaN
# std                  NaN                                   NaN
# min                  NaN                                   NaN
# 25%                  NaN                                   NaN
# 50%                  NaN                                   NaN
# 75%                  NaN                                   NaN
# max                  NaN                                   NaN
#
#                                   sub_issue  \
# count                                149371
# unique                                  207
# top     Information belongs to someone else
# freq                                  36115
# mean                                    NaN
# std                                     NaN
# min                                     NaN
# 25%                                     NaN
# 50%                                     NaN
# 75%                                     NaN
# max                                     NaN
#
#                              consumer_complaint_narrative  \
# count                                               79349
# unique                                              73166
# top     I am a victim of identity theft. The following...
# freq                                                  184
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                   company_public_response        company  \
# count                                               84720         170129
# unique                                                 11           2922
# top     Company has responded to the consumer and the ...  EQUIFAX, INC.
# freq                                                74532          27889
# mean                                                  NaN            NaN
# std                                                   NaN            NaN
# min                                                   NaN            NaN
# 25%                                                   NaN            NaN
# 50%                                                   NaN            NaN
# 75%                                                   NaN            NaN
# max                                                   NaN            NaN
#
#        state_name  zip_code           tags consumer_consent_provided  \
# count      166335  166304.0          21788                    146532
# unique         61   25081.0              3                         4
# top            CA    2301.0  Servicemember          Consent provided
# freq        21353     245.0          13349                     79359
# mean          NaN       NaN            NaN                       NaN
# std           NaN       NaN            NaN                       NaN
# min           NaN       NaN            NaN                       NaN
# 25%           NaN       NaN            NaN                       NaN
# 50%           NaN       NaN            NaN                       NaN
# 75%           NaN       NaN            NaN                       NaN
# max           NaN       NaN            NaN                       NaN
#
#        submitted_via date_sent_to_company company_response_to_consumer  \
# count         170129               170129                       170129
# unique             6                 2489                            8
# top              Web           2021-06-09      Closed with explanation
# freq          148038                  933                       143425
# mean             NaN                  NaN                          NaN
# std              NaN                  NaN                          NaN
# min              NaN                  NaN                          NaN
# 25%              NaN                  NaN                          NaN
# 50%              NaN                  NaN                          NaN
# 75%              NaN                  NaN                          NaN
# max              NaN                  NaN                          NaN
#
#        timely_response consumer_disputed  complaint_id
# count           170129              1559  1.701290e+05
# unique               2                 2           NaN
# top                Yes                No           NaN
# freq            167638              1226           NaN
# mean               NaN               NaN  3.696425e+06
# std                NaN               NaN  5.708513e+05
# min                NaN               NaN  1.454000e+03
# 25%                NaN               NaN  3.297341e+06
# 50%                NaN               NaN  3.525961e+06
# 75%                NaN               NaN  4.286683e+06
# max                NaN               NaN  5.028430e+06

# %%
df['complaint_id'].max()
# Out:
# 5028430

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2396033 entries, 0 to 2396032
# Data columns (total 18 columns):
#  #   Column                        Dtype
# ---  ------                        -----
#  0   date_received                 object
#  1   product                       object
#  2   sub_product                   object
#  3   issue                         object
#  4   sub_issue                     object
#  5   consumer_complaint_narrative  object
#  6   company_public_response       object
#  7   company                       object
#  8   state_name                    object
#  9   zip_code                      object
#  10  tags                          object
#  11  consumer_consent_provided     object
#  12  submitted_via                 object
#  13  date_sent_to_company          object
#  14  company_response_to_consumer  object
#  15  timely_response               object
#  16  consumer_disputed             object
#  17  complaint_id                  int64
# dtypes: int64(1), object(17)
# memory usage: 329.0+ MB

# %%
for col in df.columns:
    print(f"{col}: {df[col].isnull().sum()}")
# Out:
# date_received: 0
# product: 0
# sub_product: 235164
# issue: 0
# sub_issue: 641100
# consumer_complaint_narrative: 1560823
# company_public_response: 1414645
# company: 0
# state_name: 38502
# zip_code: 38719
# tags: 2105561
# consumer_consent_provided: 734001
# submitted_via: 0
# date_sent_to_company: 0
# company_response_to_consumer: 3
# timely_response: 0
# consumer_disputed: 1627574
# complaint_id: 0

# %%
for col in df.columns:
    if df[col].nunique() < 101:
        print(f"{col}: {df[col].unique()}")
# Out:
# product: ['Credit reporting, credit repair services, or other personal consumer reports'
#  'Vehicle loan or lease' 'Credit card or prepaid card' 'Debt collection'
#  'Mortgage' 'Checking or savings account'
#  'Money transfer, virtual currency, or money service' 'Student loan'
#  'Payday loan, title loan, or personal loan' 'Consumer Loan'
#  'Bank account or service' 'Money transfers' 'Credit reporting'
#  'Credit card' 'Other financial service' 'Payday loan' 'Prepaid card'
#  'Virtual currency']
# sub_product: ['Credit reporting' 'Loan' 'Store credit card' 'Credit card debt'
#  'Conventional home mortgage' 'Checking account'
#  'General-purpose prepaid card' 'Other personal consumer report'
#  'General-purpose credit card or charge card'
#  'Domestic (US) money transfer' 'Private student loan' 'Installment loan'
#  'Lease' 'Personal line of credit' 'Other debt' 'FHA mortgage'
#  'Medical debt' 'VA mortgage' 'Other banking product or service'
#  'Payday loan debt' 'Other mortgage' 'Savings account'
#  'International money transfer' 'Federal student loan servicing'
#  'I do not know' 'Other type of mortgage' 'Private student loan debt'
#  'Federal student loan debt' 'Credit card' 'CD (Certificate of Deposit)'
#  'Mobile or digital wallet' 'Payday loan' 'Auto debt' 'Reverse mortgage'
#  'Other bank product/service' 'Mortgage debt'
#  'Other (i.e. phone, health club, etc.)' 'Conventional fixed mortgage'
#  'Credit repair services' 'Home equity loan or line of credit (HELOC)'
#  'Title loan' 'Auto' 'Non-federal student loan'
#  "Traveler's check or cashier's check" 'Government benefit card' nan
#  'Virtual currency' 'Check cashing service' 'Money order'
#  'Debt settlement' 'Foreign currency exchange'
#  'Home equity loan or line of credit' 'Medical' 'Mortgage' 'Vehicle loan'
#  'Gift card' 'Conventional adjustable mortgage (ARM)'
#  'Refund anticipation check' 'Payroll card' 'Vehicle lease' 'Pawn loan'
#  'Credit repair' '(CD) Certificate of deposit'
#  'Government benefit payment card' 'General purpose card'
#  'Second mortgage' 'Other special purpose card' 'Check cashing'
#  'Cashing a check without an account' 'Federal student loan'
#  'Mobile wallet' 'Student prepaid card' 'ID prepaid card'
#  'Gift or merchant card' 'Traveler’s/Cashier’s checks'
#  'Electronic Benefit Transfer / EBT card' 'Transit card']
# company_public_response: [nan
#  'Company has responded to the consumer and the CFPB and chooses not to provide a public response'
#  'Company believes it acted appropriately as authorized by contract or law'
#  'Company disputes the facts presented in the complaint'
#  'Company believes the complaint is the result of a misunderstanding'
#  "Company can't verify or dispute the facts in the complaint"
#  'Company believes complaint caused principally by actions of third party outside the control or direction of the company'
#  'Company believes complaint is the result of an isolated error'
#  'Company chooses not to provide a public response'
#  'Company believes complaint represents an opportunity for improvement to better serve consumers'
#  'Company believes complaint relates to a discontinued policy or procedure'
#  "Company believes the complaint provided an opportunity to answer consumer's questions"]
# state_name: ['PA' 'NJ' 'WI' 'GA' 'ID' 'NY' 'MT' 'TX' 'CA' 'FL' 'CT' 'IL' 'MA' 'KY'
#  'NC' 'MI' 'OH' 'VA' 'WA' 'AL' 'MD' 'AZ' 'RI' 'TN' 'LA' 'CO' 'OR' 'IA' nan
#  'MO' 'IN' 'HI' 'NH' 'SC' 'NE' 'MS' 'MN' 'ME' 'NV' 'UT' 'DE' 'AR' 'KS'
#  'VT' 'OK' 'DC' 'PR' 'WV' 'ND' 'NM' 'AP' 'AE' 'SD' 'WY' 'VI' 'GU' 'AK'
#  'UNITED STATES MINOR OUTLYING ISLANDS' 'AA' 'AS' 'MP' 'FM' 'MH' 'PW']
# tags: [nan 'Older American' 'Servicemember' 'Older American, Servicemember']
# consumer_consent_provided: ['Consent not provided' 'Consent provided' nan 'Other' 'Consent withdrawn']
# submitted_via: ['Web' 'Referral' 'Fax' 'Postal mail' 'Phone' 'Email']
# company_response_to_consumer: ['Closed with explanation' 'In progress' 'Closed with monetary relief'
#  'Closed with non-monetary relief' 'Untimely response' 'Closed'
#  'Closed with relief' 'Closed without relief' nan]
# timely_response: ['Yes' 'No']
# consumer_disputed: [nan 'No' 'Yes']

# %%
df.nunique()
# Out:
# date_received                      3675
# product                              18
# sub_product                          76
# issue                               165
# sub_issue                           221
# consumer_complaint_narrative     748939
# company_public_response              11
# company                            6236
# state_name                           63
# zip_code                          58013
# tags                                  3
# consumer_consent_provided             4
# submitted_via                         6
# date_sent_to_company               3624
# company_response_to_consumer          8
# timely_response                       2
# consumer_disputed                     2
# complaint_id                    2396033
# dtype: int64

# %% [markdown]
# ### Retrieve Longest String Value For Non-Numeric Columns

# %%
def longest_string_length(df):
    # Select non-numeric columns
    non_numeric_cols = df.select_dtypes(exclude=['number', 'bool'])
    # Calculate the length of the longest string for each column
    return non_numeric_cols.apply(lambda col: col.dropna().astype(str).map(len).max())

# Get the result
longest_lengths = longest_string_length(df)

print(longest_lengths)
# Out:
# date_received                      10
# product                            76
# sub_product                        42
# issue                              80
# sub_issue                          85
# consumer_complaint_narrative    32317
# company_public_response           119
# company                            88
# state_name                         36
# zip_code                            7
# tags                               29
# consumer_consent_provided          20
# submitted_via                      11
# date_sent_to_company               10
# company_response_to_consumer       31
# timely_response                     3
# consumer_disputed                   3
# dtype: int64
