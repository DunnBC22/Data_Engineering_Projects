# %%
import pandas as pd

# %% [markdown]
# ### Prep Account Events

# %%
df = pd.read_csv("/Users/briandunn/Desktop/Apache Kafka- Kafka Connect/Mock Marketing Schema/data/Account.csv")

df = df.sort_values(by=['CUST_ID'], ignore_index=True)

col_names = ['cust_id', 
            'acquisition_cost', 
            'internet_banking_indicator', 
            'date_first_account_opened', 
            'date_last_account_opened', 
            'pursuit', 
            'primary_advisor_organization_id', 
            'primary_branch_proximity', 
            'primary_spoken_language', 
            'primary_written_language', 
            'satisfaction_rating_from_survey', 
            'secondary_advisor_id', 
            'secondary_advisor_organization_id', 
            'special_te']

df.to_csv('/Users/briandunn/Desktop/Apache Kafka- Kafka Connect/Mock Marketing Schema/data/Account.csv', 
          index=True,
          index_label='id',
          header=col_names
          )

df
# Out:
#           CUST_ID  ACQUISITION_COST  INTERNET_BANKING_INDICATOR  \
# 0     CUST-100067         88.307342                        True
# 1     CUST-100282         35.994341                        True
# 2     CUST-100396         82.418396                       False
# 3     CUST-100400         34.445004                        True
# 4     CUST-100417         82.580707                       False
# ...           ...               ...                         ...
# 1995  CUST-997681         81.399892                        True
# 1996  CUST-998954         20.812347                        True
# 1997  CUST-998988         53.316159                        True
# 1998  CUST-999095         26.645675                       False
# 1999  CUST-999182         83.775473                       False
#
#      DATE_FIRST_ACCOUNT_OPENED DATE_LAST_ACCOUNT_OPENED              PURSUIT  \
# 0                   2018-07-21               2018-07-21  Retirement Planning
# ...

# %% [markdown]
# ### Prep Customer Events

# %%
df = pd.read_csv("/Users/briandunn/Desktop/Apache Kafka- Kafka Connect/Mock Marketing Schema/data/Customer.csv")

df = df.sort_values(by=['CUST_ID'], ignore_index=True)

col_names = ['cust_id', 
             'gender', 
             'first_name', 
             'last_name', 
             'email', 
             'ssn', 
             'age_range', 
             'annual_income', 
             'birth_year', 
             'current_employment_start_date', 
             'customer_behavior', 
             'education_level', 
             'employment_status', 
             'marital_status', 
             'monthly_net_income', 
             'profession', 
             'retirement_age', 
             'customer_status', 
             'wallet_share_percentage']

df.to_csv('/Users/briandunn/Desktop/Apache Kafka- Kafka Connect/Mock Marketing Schema/data/Customer.csv', 
          index=True,
          index_label='id',
          header=col_names
          )

df
# Out:
#           CUST_ID  GENDER  FIRST_NAME   LAST_NAME  \
# 0     CUST-100067  Female        Brad      Thomas
# 1     CUST-100282    Male       Tonia     Scahill
# 2     CUST-100396  Female      Ashley        Hill
# 3     CUST-100400    Male     Jasmine      Fowler
# 4     CUST-100417    Male        Mark    Harrison
# ...           ...     ...         ...         ...
# 1995  CUST-997681  Female      Curtis       Green
# 1996  CUST-998954    Male    Victoria       Gomez
# 1997  CUST-998988  Female  Maximilian  Habbergham
# 1998  CUST-999095    Male       Orren      Cullin
# 1999  CUST-999182  Female   Archibald     Chevins
#
#                             EMAIL          SSN    AGE_RANGE ANNUAL_INCOME  \
# 0           heatherhunt@yahoo.com  XXX-XX-6919  65 and over  $105,313.00
# 1        tscahill9b@earthlink.net  XXX-XX-8125  65 and over  $266,280.00
# 2         andrealewis@hotmail.com  XXX-XX-5735  65 and over  $231,983.00
# ...

# %% [markdown]
# ### Prep Financials Events

# %%
df = pd.read_csv("/Users/briandunn/Desktop/Apache Kafka- Kafka Connect/Mock Marketing Schema/data/Financials.csv")

df = df.sort_values(by=['CUST_ID'], ignore_index=True)

col_names = ['cust_id', 
             'monthly_housing_cost', 
             'contact_preference', 
             'credit_authority_level', 
             'credit_score', 
             'credit_utilization', 
             'debt_service_coverage_ratio']

df.to_csv('/Users/briandunn/Desktop/Apache Kafka- Kafka Connect/Mock Marketing Schema/data/Financials.csv', 
          index=True,
          index_label='id',
          header=col_names
          )

df
# Out:
#           CUST_ID  MONTHLY_HOUSING_COST CONTACT_PREFERENCE  \
# 0     CUST-100067                  1856               mail
# 1     CUST-100282                  4284               mail
# 2     CUST-100396                  3632              phone
# 3     CUST-100400                  3340              email
# 4     CUST-100417                   717              email
# ...           ...                   ...                ...
# 1995  CUST-997681                  2632              phone
# 1996  CUST-998954                  7448               mail
# 1997  CUST-998988                  5588               mail
# 1998  CUST-999095                  1310              phone
# 1999  CUST-999182                  1537              email
#
#      CREDIT_AUTHORITY_LEVEL  CREDIT_SCORE  CREDIT_UTILIZATION  \
# 0                 Very High           726            0.725897
# 1                       Low           806            0.312935
# 2                 Very High           722            0.493682
# ...

# %% [markdown]
# ### Prep Household Events

# %%
df = pd.read_csv("/Users/briandunn/Desktop/Apache Kafka- Kafka Connect/Mock Marketing Schema/data/Household.csv")

df = df.sort_values(by=['CUST_ID'], ignore_index=True)#.reset_index(drop=True)

col_names = ['cust_id', 
             'household_id', 
             'household_address', 
             'household_city', 
             'household_country', 
             'household_state', 
             'household_zip_code', 
             'address_last_changed_date', 
             'number_of_dependent_adults', 
             'number_of_dependent_children', 
             'family_size', 
             'head_of_household_indicator', 
             'home_owner_indicator', 
             'urban_code', 
             'primary_advisor_id']

df.to_csv('/Users/briandunn/Desktop/Apache Kafka- Kafka Connect/Mock Marketing Schema/data/Household.csv', 
          index=True,
          index_label='id',
          header=col_names
          )

df
# Out:
#           CUST_ID HOUSEHOLD_ID                ADDRESS            CITY  \
# 0     CUST-100067  HHID-100067        94 E 22nd St #4         Fairfax
# 1     CUST-100282  HHID-100282           52 Haas Pass      Charleston
# 2     CUST-100396  HHID-100396      915 Lafayette Ave       Bethlehem
# 3     CUST-100400  HHID-100400        43986 E 67th St  South El Monte
# 4     CUST-100417  HHID-100417       6 Bear Tavern Rd    West Chester
# ...           ...          ...                    ...             ...
# 1995  CUST-997681  HHID-997681   461 Prospect Pl #316          Euless
# 1996  CUST-998954  HHID-998954           1 N San Saba            Erie
# 1997  CUST-998988  HHID-998988      8 Armistice Place         Olympia
# 1998  CUST-999095  HHID-999095        702 Manley Hill      Washington
# 1999  CUST-999182  HHID-999182  9480 Lotheville Trail         Houston
#
#             COUNTRY                 STATE    ZIP ADDRESS_LAST_CHANGED_DATE  \
# ...

# %% [markdown]
# ### Prep Marketing Events

# %%
df = pd.read_csv("/Users/briandunn/Desktop/Apache Kafka- Kafka Connect/Mock Marketing Schema/data/Marketing.csv")

df = df.sort_values(by=['CUST_ID'], ignore_index=True)#.reset_index(drop=True)

col_names = ['cust_id', 
             'advertising_indicator', 
             'attachment_allowed_indicator', 
             'preferred_communication_form', 
             'importance_level_code', 
             'influence_score', 
             'market_group', 
             'loyalty_rating_code', 
             'recorded_voice_sample_id', 
             'referrals_value_code', 
             'relationship_start_date']

df.to_csv('/Users/briandunn/Desktop/Apache Kafka- Kafka Connect/Mock Marketing Schema/data/Marketing.csv', 
          index=True,
          index_label='id',
          header=col_names
          )

df
# Out:
#           CUST_ID  ADVERTISING_INDICATOR  ATTACHMENT_ALLOWED_INDICATOR  \
# 0     CUST-100067                   True                          True
# 1     CUST-100282                   True                         False
# 2     CUST-100396                   True                          True
# 3     CUST-100400                   True                          True
# 4     CUST-100417                   True                          True
# ...           ...                    ...                           ...
# 1995  CUST-997681                   True                          True
# 1996  CUST-998954                   True                          True
# 1997  CUST-998988                   True                         False
# 1998  CUST-999095                   True                         False
# 1999  CUST-999182                   True                          True
#
#      PREFERRED_COMMUNICATION_FORM IMPORTANCE_LEVEL_CODE  INFLUENCE_SCORE  \
# ...
